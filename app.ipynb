# %%
from flask import Flask, render_template, request, redirect, session, url_for
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    if prop["Published"]["checkbox"]:
        post = {
            "PageId": db["results"][i]["id"],
            "Title": prop["Page"]["title"][0]["plain_text"],
            "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
            "Date": prop["Date"]["date"]["start"],
            "LastEditedTime": db["results"][i]["last_edited_time"][:10],
            "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
            "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
            "OGImage":ogimege[0]["file"]["url"] if len(ogimege)> 0 else None,
            "Rank": prop["Rank"]["number"]}
        tags.extend(post["Tags"])
        posts.append(post)
tags_set=list(set(tags))

# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
def get_title(html):
    """Scrape page title."""
    title = None
    if type(html.title)==str:
        title = html.title.string
    elif html.find("meta", property="og:title"):
        title = html.find("meta", property="og:title").get('content')
    elif html.find("meta", property="twitter:title"):
        title = html.find("meta", property="twitter:title").get('content')
    elif html.find("h1"):
        title = html.find("h1").string
    return title


def get_description(html):
    """Scrape page description."""
    description = None
    if html.find("meta", property="description"):
        description = html.find("meta", property="description").get('content')
    elif html.find("meta", property="og:description"):
        description = html.find("meta", property="og:description").get('content')
    elif html.find("meta", property="twitter:description"):
        description = html.find("meta", property="twitter:description").get('content')
    elif html.find("p"):
        description = html.find("p").contents
    return description


def get_image(html):
    """Scrape share image."""
    image = None
    if html.find("meta", property="image"):
        image = html.find("meta", property="image").get('content')
    elif html.find("meta", property="og:image"):
        image = html.find("meta", property="og:image").get('content')
    elif html.find("meta", property="twitter:image"):
        image = html.find("meta", property="twitter:image").get('content')
    elif html.find("img", src=True):
        image = html.find("img").get('src')
    return image

def generate_preview(url):
    req = requests.get(url, headers)
    html = BeautifulSoup(req.content, 'html.parser')
    meta_data = {
       'title': get_title(html),
       'description': get_description(html),
       'image': get_image(html),
    }
    return meta_data


def make_page(p):
    item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }

        elif item_type in ["link_preview","bookmark","embed"]:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Url":item[i][item_type]["url"],
                "LinkPreview": generate_preview(item[i][item_type]["url"]),
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

# %%
app = Flask(__name__)
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/','Blog':'/blog','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/")
def index():
    return render_template("index.html",labellist=labellist)

@app.route("/blog", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    return render_template("blog.html",labellist=labellist,posts=posts,tags=tags_set,tagname=0)

@app.route("/blog/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    return render_template("blog.html",labellist=labellist,posts=tag_page,tags=tags_set,tagname=Tag)


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:47:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'idareの特徴',
#                           'text': {'content': 'idareの特徴', 'link': None},
#                           'type': 'text'}]},
#   'id': 'e496e3fa-c211-48e5-bbc9-3c0c81d64ffa',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:47:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '3dsなし',
#                                    'text': {'content': '3dsなし', 'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:29:00.000Z',
#   'has_children': False,
#   'id': 'c4193138-bf11-4b70-ac3c-8fdd04de79ca',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:48:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'クレカチャージ可能',
#                                    'text': {'content': 'クレカチャージ可能',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:29:00.000Z',
#   'has_children': False,
#   'id': '648575d4-9fd7-4d3a-9ec5-35bd89a0487d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:48:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:34:00.000Z',
#   'has_children': False,
#   'id': 'd5a20837-8ef8-4310-8949-ca17229c8dcb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:12:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ちょっと試した限りだとトヨタウォレットなどプリペイドカードからのチャージNG',
#                       'text': {'content': 'ちょっと試した限りだとトヨタウォレットなどプリペイドカードからのチャージNG',
#                                'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T20:02:00.000Z',
#   'has_children': False,
#   'id': 'f9383bff-fa12-43f4-b1c2-dbdf65ea5215',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-29T05:42:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': True,
#                                       'code': False,
#                                       'color': 'red',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'revolutはいけた。→いけなくなってた',
#                       'text': {'content': 'revolutはいけた。→いけなくなってた',
#                                'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T20:03:00.000Z',
#   'has_children': False,
#   'id': 'e095ecc7-417e-4aa7-abd3-82569a75ec52',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:12:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ついでにlinepayカードはポイント対象外らしい',
#                       'text': {'content': 'ついでにlinepayカードはポイント対象外らしい',
#                                'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '溜まっている額の',
#                                    'text': {'content': '溜まっている額の',
#                                             'link': None},
#                                    'type': 'text'},
#                                   {'annotations': {'bold': True,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '年利2パー',
#                                    'text': {'content': '年利2パー', 'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:30:00.000Z',
#   'has_children': False,
#   'id': '3777b228-1c36-476f-8eb3-52f1d352046f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:49:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:31:00.000Z',
#   'has_children': False,
#   'id': '22213656-5755-40d5-96ef-274d87176bcc',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:52:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ただ毎月のチャージ額の20%までとのことチャージしないとボーナスなし。毎月定額チャージ可能500円から。',
#                       'text': {'content': 'ただ毎月のチャージ額の20%までとのことチャージしないとボーナスなし。毎月定額チャージ可能500円から。',
#                                'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T10:03:00.000Z',
#   'has_children': False,
#   'id': 'd26229f9-d76e-446c-88d9-8de665f8a771',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:52:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:37:00.000Z',
#   'has_children': False,
#   'id': 'fe2180a7-f62d-44cd-98cb-3bb20b94c21c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:52:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:30:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'トヨタウォレットとの比較',
#                           'text': {'content': 'トヨタウォレットとの比較', 'link': None},
#                           'type': 'text'}]},
#   'id': 'bc52beb0-36cd-414c-aa98-b36284969b51',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:54:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:30:00.000Z',
#   'has_children': False,
#   'id': '60d8577f-72c9-4331-9329-ccbcf3b0b2a6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:50:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'トヨタウォレットとの比較で考えます。（クレカは共通なので適当に1%）',
#                           'text': {'content': 'トヨタウォレットとの比較で考えます。（クレカは共通なので適当に1%）',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'トヨタウォレットは単純でキャッシュ経由として',
#                                    'text': {'content': 'トヨタウォレットは単純でキャッシュ経由として',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:31:00.000Z',
#   'has_children': False,
#   'id': '3dc528f7-7938-4e7b-af9e-1f3faf35e717',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:50:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:32:00.000Z',
#   'has_children': False,
#   'id': '50e9baa3-eeb4-450b-98fd-ab91604ff030',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:12:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ1＋キャッシュ0.2＋トヨタウォレット1=',
#                           'text': {'content': 'クレカ1＋キャッシュ0.2＋トヨタウォレット1=',
#                                    'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '2.2%',
#                           'text': {'content': '2.2%', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '一方idareは',
#                                    'text': {'content': '一方idareは',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:33:00.000Z',
#   'has_children': False,
#   'id': '51659f32-5f41-4692-9041-97b3616f6c38',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:50:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:33:00.000Z',
#   'has_children': False,
#   'id': 'c9fdce24-537a-49c2-be2d-05cfb789f291',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-29T05:42:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ分1＋ldare x%=',
#                           'text': {'content': 'クレカ分1＋ldare x%=', 'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '1+x%',
#                           'text': {'content': '1+x%', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:35:00.000Z',
#   'has_children': False,
#   'id': 'ca6dbab3-c808-48d8-88fe-04254da78142',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T09:35:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ということでidareの還元率次第となります',
#                           'text': {'content': 'ということでidareの還元率次第となります',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '一年で2%、つまり一月あたり0.166％',
#                                    'text': {'content': '一年で2%、つまり一月あたり0.166％',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:35:00.000Z',
#   'has_children': False,
#   'id': '958cc25a-5f51-4c9b-bf40-f65db408fcf1',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:52:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:52:00.000Z',
#   'has_children': False,
#   'id': '9a797b38-aecf-4d2d-9b8c-434fe3b8307e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:53:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': '30000円残高あるとしても毎月のボーナスは48円なので毎月500円積み立てていればボーナスは貰える',
#                       'text': {'content': '30000円残高あるとしても毎月のボーナスは48円なので毎月500円積み立てていればボーナスは貰える',
#                                'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T10:03:00.000Z',
#   'has_children': False,
#   'id': 'a2e81967-860b-414c-9854-7dbd9e513ca5',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-29T05:42:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '実際トヨタウォレットよりお得なのは還元率の差1.2%が埋められれば良いので1.2÷0.166で',
#                           'text': {'content': '実際トヨタウォレットよりお得なのは還元率の差1.2%が埋められれば良いので1.2÷0.166で',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:53:00.000Z',
#   'has_children': False,
#   'id': 'a3e3ec2a-4c73-459b-92fe-3784eb236555',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-29T05:43:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'orange',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '7.2ヶ月入れっぱにしていればトヨタウォレット以上',
#                           'text': {'content': '7.2ヶ月入れっぱにしていればトヨタウォレット以上',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:54:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使い道の検討',
#                           'text': {'content': '使い道の検討', 'link': None},
#                           'type': 'text'}]},
#   'id': '214b7eaa-dc79-457d-97cf-d62429675574',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:54:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T09:36:00.000Z',
#   'has_children': False,
#   'id': '528eb844-ed8b-4903-a68b-733fd62c5689',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:55:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使い道がオンライン決済かpaypayのみなのであまり大金を入れておきたくはない。',
#                           'text': {'content': '使い道がオンライン決済かpaypayのみなのであまり大金を入れておきたくはない。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:55:00.000Z',
#   'has_children': False,
#   'id': 'f45ea2e3-3daa-41ea-9dec-b45d28cae24e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:56:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '最低積み立ての毎月500円でボーナスをもらえる範囲は',
#                           'text': {'content': '最低積み立ての毎月500円でボーナスをもらえる範囲は',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:56:00.000Z',
#   'has_children': False,
#   'id': 'a3782353-942e-496d-ac70-76760dd56959',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:57:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '500*0.20/0.166=60240円までなら満額もらえる',
#                           'text': {'content': '500*0.20/0.166=60240円までなら満額もらえる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T10:10:00.000Z',
#   'has_children': False,
#   'id': '77029dae-fb42-44cc-bb60-db47a5a29f8b',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:04:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ということでキャンペーンなどで大目に決済しておきたいときには5万程度までいれておくのはあり。',
#                           'text': {'content': 'ということでキャンペーンなどで大目に決済しておきたいときには5万程度までいれておくのはあり。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:57:00.000Z',
#   'has_children': False,
#   'id': '7b154c05-672d-45f0-b2c2-d725485241e1',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:09:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'その他毎月の積立500円を毎月決済があることで得するクレカにすることで効果あるかなと',
#                           'text': {'content': 'その他毎月の積立500円を毎月決済があることで得するクレカにすることで効果あるかなと',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T19:58:00.000Z',
#   'has_children': False,
#   'id': '669d20ff-1b39-4bee-af79-31ca4c2b117c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T19:59:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '私はauじぶん銀行の金利を上げるためaupayカードを使おうかなと。',
#                           'text': {'content': '私はauじぶん銀行の金利を上げるためaupayカードを使おうかなと。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T20:05:00.000Z',
#   'has_children': False,
#   'id': 'a28c40fb-9f56-4c30-b455-bd078c38d326',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '毎月の少額決済、アマギフとかネオモバ証券くらいなのでidareも採用かな。',
#                           'text': {'content': '毎月の少額決済、アマギフとかネオモバ証券くらいなのでidareも採用かな。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-28T20:07:00.000Z',
#   'has_children': False,
#   'id': 'be118f04-d44e-422a-81ff-4cab1b91a3a1',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-28T20:10:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使途に制約かかるとはいえほぼノーリスクで年利2%はおいしい。そのうち下がるだろうけど...',
#                           'text': {'content': '使途に制約かかるとはいえほぼノーリスクで年利2%はおいしい。そのうち下がるだろうけど...',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-29T05:43:00.000Z',
#   'has_children': False,
#   'id': '5b403ad2-0891-4122-a070-8eb8a2aa409c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-29T05:43:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'type': 'paragraph'}]
# [{'HasChildren': False,
#   'Id': 'e496e3fa-c211-48e5-bbc9-3c0c81d64ffa',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'idareの特徴',
#                           'text': {'content': 'idareの特徴', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': 'c4193138-bf11-4b70-ac3c-8fdd04de79ca',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '3dsなし',
#                           'text': {'content': '3dsなし', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '648575d4-9fd7-4d3a-9ec5-35bd89a0487d',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカチャージ可能',
#                           'text': {'content': 'クレカチャージ可能', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': 'd5a20837-8ef8-4310-8949-ca17229c8dcb',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ちょっと試した限りだとトヨタウォレットなどプリペイドカードからのチャージNG',
#                       'text': {'content': 'ちょっと試した限りだとトヨタウォレットなどプリペイドカードからのチャージNG',
#                                'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Id': 'f9383bff-fa12-43f4-b1c2-dbdf65ea5215',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': True,
#                                       'code': False,
#                                       'color': 'red',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'revolutはいけた。→いけなくなってた',
#                       'text': {'content': 'revolutはいけた。→いけなくなってた',
#                                'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Id': 'e095ecc7-417e-4aa7-abd3-82569a75ec52',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ついでにlinepayカードはポイント対象外らしい',
#                       'text': {'content': 'ついでにlinepayカードはポイント対象外らしい',
#                                'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Id': '3777b228-1c36-476f-8eb3-52f1d352046f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '溜まっている額の',
#                           'text': {'content': '溜まっている額の', 'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '年利2パー',
#                           'text': {'content': '年利2パー', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '22213656-5755-40d5-96ef-274d87176bcc',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': 'ただ毎月のチャージ額の20%までとのことチャージしないとボーナスなし。毎月定額チャージ可能500円から。',
#                       'text': {'content': 'ただ毎月のチャージ額の20%までとのことチャージしないとボーナスなし。毎月定額チャージ可能500円から。',
#                                'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Id': 'd26229f9-d76e-446c-88d9-8de665f8a771',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'fe2180a7-f62d-44cd-98cb-3bb20b94c21c',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'bc52beb0-36cd-414c-aa98-b36284969b51',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'トヨタウォレットとの比較',
#                           'text': {'content': 'トヨタウォレットとの比較', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '60d8577f-72c9-4331-9329-ccbcf3b0b2a6',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'トヨタウォレットとの比較で考えます。（クレカは共通なので適当に1%）',
#                           'text': {'content': 'トヨタウォレットとの比較で考えます。（クレカは共通なので適当に1%）',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '3dc528f7-7938-4e7b-af9e-1f3faf35e717',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'トヨタウォレットは単純でキャッシュ経由として',
#                           'text': {'content': 'トヨタウォレットは単純でキャッシュ経由として',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '50e9baa3-eeb4-450b-98fd-ab91604ff030',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ1＋キャッシュ0.2＋トヨタウォレット1=',
#                           'text': {'content': 'クレカ1＋キャッシュ0.2＋トヨタウォレット1=',
#                                    'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '2.2%',
#                           'text': {'content': '2.2%', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '51659f32-5f41-4692-9041-97b3616f6c38',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '一方idareは',
#                           'text': {'content': '一方idareは', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': 'c9fdce24-537a-49c2-be2d-05cfb789f291',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ分1＋ldare x%=',
#                           'text': {'content': 'クレカ分1＋ldare x%=', 'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '1+x%',
#                           'text': {'content': '1+x%', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'ca6dbab3-c808-48d8-88fe-04254da78142',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ということでidareの還元率次第となります',
#                           'text': {'content': 'ということでidareの還元率次第となります',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '958cc25a-5f51-4c9b-bf40-f65db408fcf1',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '一年で2%、つまり一月あたり0.166％',
#                           'text': {'content': '一年で2%、つまり一月あたり0.166％',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '9a797b38-aecf-4d2d-9b8c-434fe3b8307e',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': '30000円残高あるとしても毎月のボーナスは48円なので毎月500円積み立てていればボーナスは貰える',
#                       'text': {'content': '30000円残高あるとしても毎月のボーナスは48円なので毎月500円積み立てていればボーナスは貰える',
#                                'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Id': 'a2e81967-860b-414c-9854-7dbd9e513ca5',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '実際トヨタウォレットよりお得なのは還元率の差1.2%が埋められれば良いので1.2÷0.166で',
#                           'text': {'content': '実際トヨタウォレットよりお得なのは還元率の差1.2%が埋められれば良いので1.2÷0.166で',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'a3e3ec2a-4c73-459b-92fe-3784eb236555',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'orange',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '7.2ヶ月入れっぱにしていればトヨタウォレット以上',
#                           'text': {'content': '7.2ヶ月入れっぱにしていればトヨタウォレット以上',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '214b7eaa-dc79-457d-97cf-d62429675574',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使い道の検討',
#                           'text': {'content': '使い道の検討', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '528eb844-ed8b-4903-a68b-733fd62c5689',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使い道がオンライン決済かpaypayのみなのであまり大金を入れておきたくはない。',
#                           'text': {'content': '使い道がオンライン決済かpaypayのみなのであまり大金を入れておきたくはない。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'f45ea2e3-3daa-41ea-9dec-b45d28cae24e',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '最低積み立ての毎月500円でボーナスをもらえる範囲は',
#                           'text': {'content': '最低積み立ての毎月500円でボーナスをもらえる範囲は',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'a3782353-942e-496d-ac70-76760dd56959',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '500*0.20/0.166=60240円までなら満額もらえる',
#                           'text': {'content': '500*0.20/0.166=60240円までなら満額もらえる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '77029dae-fb42-44cc-bb60-db47a5a29f8b',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ということでキャンペーンなどで大目に決済しておきたいときには5万程度までいれておくのはあり。',
#                           'text': {'content': 'ということでキャンペーンなどで大目に決済しておきたいときには5万程度までいれておくのはあり。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '7b154c05-672d-45f0-b2c2-d725485241e1',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'その他毎月の積立500円を毎月決済があることで得するクレカにすることで効果あるかなと',
#                           'text': {'content': 'その他毎月の積立500円を毎月決済があることで得するクレカにすることで効果あるかなと',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '669d20ff-1b39-4bee-af79-31ca4c2b117c',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '私はauじぶん銀行の金利を上げるためaupayカードを使おうかなと。',
#                           'text': {'content': '私はauじぶん銀行の金利を上げるためaupayカードを使おうかなと。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'a28c40fb-9f56-4c30-b455-bd078c38d326',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '毎月の少額決済、アマギフとかネオモバ証券くらいなのでidareも採用かな。',
#                           'text': {'content': '毎月の少額決済、アマギフとかネオモバ証券くらいなのでidareも採用かな。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'be118f04-d44e-422a-81ff-4cab1b91a3a1',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '使途に制約かかるとはいえほぼノーリスクで年利2%はおいしい。そのうち下がるだろうけど...',
#                           'text': {'content': '使途に制約かかるとはいえほぼノーリスクで年利2%はおいしい。そのうち下がるだろうけど...',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '5b403ad2-0891-4122-a070-8eb8a2aa409c',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'paragraph'}]
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /blog/idare HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/blog.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/notion-block.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/blog-parts.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2022 01:20:56] "GET /favicon.ico HTTP/1.1" 404 -
