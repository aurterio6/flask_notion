# %%
from flask import Flask, render_template, request, redirect, session, url_for,send_from_directory
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    if prop["Page"]["title"][0]["plain_text"]=="biography":
        bio_id=db["results"][i]["id"]
    if prop["Published"]["checkbox"]:
        post = {
            "PageId": db["results"][i]["id"],
            "Title": prop["Page"]["title"][0]["plain_text"],
            "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
            "Date": prop["Date"]["date"]["start"],
            "LastEditedTime": db["results"][i]["last_edited_time"][:10],
            "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
            "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
            "OGImage":ogimege[0]["external"]["url"] if len(ogimege)> 0 else None,
            "Rank": prop["Rank"]["number"]}
        tags.extend(post["Tags"])
        posts.append(post)
tags_set=list(set(tags))

# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
def get_title(html):
    """Scrape page title."""
    title = None
    if type(html.title)==str:
        title = html.title.string
    elif html.find("meta", property="og:title"):
        title = html.find("meta", property="og:title").get('content')
    elif html.find("meta", property="twitter:title"):
        title = html.find("meta", property="twitter:title").get('content')
    elif html.find("h1"):
        title = html.find("h1").string
    return title


def get_description(html):
    """Scrape page description."""
    description = None
    if html.find("meta", property="description"):
        description = html.find("meta", property="description").get('content')
    elif html.find("meta", property="og:description"):
        description = html.find("meta", property="og:description").get('content')
    elif html.find("meta", property="twitter:description"):
        description = html.find("meta", property="twitter:description").get('content')
    elif html.find("p"):
        description = html.find("p").contents
    return description


def get_image(html):
    """Scrape share image."""
    image = None
    if html.find("meta", property="image"):
        image = html.find("meta", property="image").get('content')
    elif html.find("meta", property="og:image"):
        image = html.find("meta", property="og:image").get('content')
    elif html.find("meta", property="twitter:image"):
        image = html.find("meta", property="twitter:image").get('content')
    elif html.find("img", src=True):
        image = html.find("img").get('src')
    return image

def generate_preview(url):
    req = requests.get(url, headers)
    html = BeautifulSoup(req.content, 'html.parser')
    meta_data = {
       'title': get_title(html),
       'description': get_description(html),
       'image': get_image(html),
    }
    return meta_data


def make_page(p):
    if p=="bio":
        item = notion.blocks.children.list(block_id=bio_id)["results"]
    else:
        item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }

        elif item_type in ["link_preview","bookmark","embed"]:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Url":item[i][item_type]["url"],
                "LinkPreview": generate_preview(item[i][item_type]["url"]),
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

def makesitemap():
    import xml.etree.ElementTree as ET

    urls = [
        "https://flasknotionblog.herokuapp.com/",
        "https://flasknotionblog.herokuapp.com/top"
    ]
    for p in range(len(posts)):
        urls.append("https://flasknotionblog.herokuapp.com/"+posts[p]["Slug"])
    urlset = ET.Element('urlset')
    urlset.set("xmlns", "http://www.sitemaps.org/schemas/sitemap/0.9")
    tree = ET.ElementTree(element=urlset)

    for u in range(len(urls)):
        url=urls[u]
        url_element = ET.SubElement(urlset, 'url')
        loc = ET.SubElement(url_element, 'loc')
        loc.text = url
        lastmod = ET.SubElement(url_element, 'lastmod')
        if u<2:
            lastmod.text = "2022-04-01"
        else:
            lastmod.text = posts[u-2]["LastEditedTime"]

    path = './static/sitemap.txt'
    f = open(path, 'w')
    for url in urls:
        f.write(url+"\n")
    f.close()
    tree.write('static/sitemap.xml', encoding='utf-8', xml_declaration=True)
#makesitemap()

# %%
app = Flask(__name__, static_folder='static')
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/top','Blog':'/','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/top")
def index():
    blocks=make_page("bio")
    return render_template("index.html",blocks=blocks,labellist=labellist,tags=tags_set)

@app.route("/", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    blocks=make_page("bio")
    pprint(posts)
    return render_template("blog.html",labellist=labellist,posts=posts,blocks=blocks,tags=tags_set,tagname=0)

@app.route("/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    blocks=make_page("bio")
    return render_template("blog.html",labellist=labellist,posts=tag_page,blocks=blocks,tags=tags_set,tagname=Tag)

@app.route('/robots.txt')
@app.route('/sitemap.xml')
@app.route('/sitemap.txt')
@app.route('/default.jpg')
@app.route('/favicon.ico')
def static_from_root():
    return send_from_directory(app.static_folder, request.path[1:])

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Oct/2022 15:41:34] "GET / HTTP/1.1" 200 -
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:38:00.000Z',
#   'has_children': False,
#   'id': '848affa9-92af-4260-9ff8-2f845c49fc51',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T14:00:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '頑張って生きているけれどSNSで発言するほどでもないのでサイトを作ってみました。本当はエンジニアに憧れがあるので趣味の一環です。ちょっとずつ作ってみます。今は初めてコードに触るので、いつかいい感じにしたいです。きっかけとしては新しいアプリが好きなので色々試していたところnotionに出会い、色々便利な使い方を調べているうちにblogもできるらしいというのをみて、色々始めました。このサイトの内容としては、私のライフログとして、その時々の関心ごとを記事にしていきます。2022年の今はプログラミングやポイ活などに関心があるのでそういった記事が増えると思います。',
#                           'text': {'content': '頑張って生きているけれどSNSで発言するほどでもないのでサイトを作ってみました。本当はエンジニアに憧れがあるので趣味の一環です。ちょっとずつ作ってみます。今は初めてコードに触るので、いつかいい感じにしたいです。きっかけとしては新しいアプリが好きなので色々試していたところnotionに出会い、色々便利な使い方を調べているうちにblogもできるらしいというのをみて、色々始めました。このサイトの内容としては、私のライフログとして、その時々の関心ごとを記事にしていきます。2022年の今はプログラミングやポイ活などに関心があるのでそういった記事が増えると思います。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:39:00.000Z',
#   'has_children': False,
#   'id': '9d44dc2c-f052-4c58-8a65-8e801cfc999f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:51:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '私のバックグラウンドとしては、建築の大学を出ていますが無関係の事務仕事をしています。無料の趣味として2021年からプログラミングを初めて、色々楽しんでいますが、Google検索でやりたい動作をひたすらコピペしているので、全く体系だった知識はありません。基本的には最初に触ったpythonで機械学習だったり、簡単なボードゲームを仲間内で遊ぶために作ったり、今はブログだったりを作っています。githubの使い方はいまいちわからないのと出しちゃいけない情報を出してないか不安なので基本非公開にしています。',
#                           'text': {'content': '私のバックグラウンドとしては、建築の大学を出ていますが無関係の事務仕事をしています。無料の趣味として2021年からプログラミングを初めて、色々楽しんでいますが、Google検索でやりたい動作をひたすらコピペしているので、全く体系だった知識はありません。基本的には最初に触ったpythonで機械学習だったり、簡単なボードゲームを仲間内で遊ぶために作ったり、今はブログだったりを作っています。githubの使い方はいまいちわからないのと出しちゃいけない情報を出してないか不安なので基本非公開にしています。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:47:00.000Z',
#   'has_children': False,
#   'id': '166bfc48-27f4-42ff-b431-d251bf3c6b8d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:58:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ポイ活に関しては、ポイントサイトなどを使ったポイ活のためにアクションをするというよりは、クレジットカードやプリペイドカードを集めるのが好きなのでその時々の高還元率を考えたりしていきます。キャンペーンも自然と知ったら参加しますが、参加し損ねたキャンペーンとか見つけると悔しいのであまり情報収集はしていません。',
#                           'text': {'content': 'ポイ活に関しては、ポイントサイトなどを使ったポイ活のためにアクションをするというよりは、クレジットカードやプリペイドカードを集めるのが好きなのでその時々の高還元率を考えたりしていきます。キャンペーンも自然と知ったら参加しますが、参加し損ねたキャンペーンとか見つけると悔しいのであまり情報収集はしていません。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:50:00.000Z',
#   'has_children': False,
#   'id': 'b0e420fa-8733-4efb-aed6-456121f95f12',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:54:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'その他今後の計画としては一人旅などをしていきたいのでその記録だったりつけていきたいです。ちなみに直近の悩みとしてはブログのトップページしかgoogle様に見つけていただいていないのでそこをどうにかしたいです。この自己紹介もその対策として長文あったら改善するかな、として書いています。その他、アフィリエイトは世の中をよくしているとはとても思えないので今のところやらないつもりです。おすすめの商品のリンクを貼ったとしてもそれはリンクでしかないはずです。',
#                           'text': {'content': 'その他今後の計画としては一人旅などをしていきたいのでその記録だったりつけていきたいです。ちなみに直近の悩みとしてはブログのトップページしかgoogle様に見つけていただいていないのでそこをどうにかしたいです。この自己紹介もその対策として長文あったら改善するかな、として書いています。その他、アフィリエイトは世の中をよくしているとはとても思えないので今のところやらないつもりです。おすすめの商品のリンクを貼ったとしてもそれはリンクでしかないはずです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:54:00.000Z',
#   'has_children': False,
#   'id': 'd34a20d3-c547-4cad-b973-acaa96419b01',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:55:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'いくつかブログを試しているところなので以下にリンク',
#                           'text': {'content': 'いくつかブログを試しているところなので以下にリンク',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:55:00.000Z',
#   'has_children': False,
#   'id': 'e93f64db-6254-4d4c-baeb-05b75063c69b',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:55:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://ameblo.jp/pelissier',
#                           'plain_text': 'アメブロ',
#                           'text': {'content': 'アメブロ',
#                                    'link': {'url': 'https://ameblo.jp/pelissier'}},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:55:00.000Z',
#   'has_children': False,
#   'id': '3ff31220-9752-475a-adf6-3b7abb46496c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:56:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://www.pappardelle-nono.tk/',
#                           'plain_text': 'vercelを使ったnotionブログ',
#                           'text': {'content': 'vercelを使ったnotionブログ',
#                                    'link': {'url': 'https://www.pappardelle-nono.tk/'}},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:56:00.000Z',
#   'has_children': False,
#   'id': '13d8c340-5ac3-4166-b226-dae23743cb21',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:57:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://flasknotionblog.herokuapp.com/',
#                           'plain_text': 'herokuを使ったnotionブログ',
#                           'text': {'content': 'herokuを使ったnotionブログ',
#                                    'link': {'url': 'https://flasknotionblog.herokuapp.com/'}},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:57:00.000Z',
#   'has_children': False,
#   'id': '055fe739-1e29-459c-91e4-7d5fe40a48fb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:57:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://ilmiolifelog.herokuapp.com/',
#                           'plain_text': 'wordpressを使ったnotionからコピペしているブログ',
#                           'text': {'content': 'wordpressを使ったnotionからコピペしているブログ',
#                                    'link': {'url': 'https://ilmiolifelog.herokuapp.com/'}},
#                           'type': 'text'}]},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-02T13:57:00.000Z',
#   'has_children': False,
#   'id': '07d52094-080a-4a9f-879e-d7698bcfa762',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-02T13:57:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'parent': {'page_id': '1830b5be-edc6-4a7c-a89e-41bb1837d667',
#              'type': 'page_id'},
#   'type': 'paragraph'}]
# [{'Date': '2022-10-13',
#   'Excerpt': 'また改悪されて考えないと',
#   'LastEditedTime': '2022-10-13',
#   'OGImage': 'https://res.cloudinary.com/drnj48esm/image/upload/v1665633686/CCDBD165-5609-478A-87D1-D1815613ACD8_pt8ozg.jpg',
#   'PageId': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#   'Rank': 1,
#   'Slug': 'aurevo',
#   'Tags': ['お金系'],
#   'Title': 'Revolut,toyotawalletの使い方、チャージ方法【2022.11:auプリペ改悪後】'},
#  {'Date': '2022-08-28',
#   'Excerpt': 'お金持ちになりたいけど、、、',
#   'LastEditedTime': '2022-08-30',
#   'OGImage': None,
#   'PageId': 'a6c431b6-4009-4d70-8b9f-e721097c939a',
#   'Rank': None,
#   'Slug': 'bottot',
#   'Tags': ['お金系'],
#   'Title': '何回目かの自動売買BOTつくった日記'},
#  {'Date': '2022-05-01',
#   'Excerpt': 'スムーズに行けば所要1時間くらい？',
#   'LastEditedTime': '2022-07-28',
#   'OGImage': None,
#   'PageId': '3ecdf675-3e0c-4643-aeb6-37394b5bf101',
#   'Rank': 1,
#   'Slug': 'wordpress',
#   'Tags': ['programing'],
#   'Title': '無料でwordpressを使いたい！【2022年 heroku】'},
#  {'Date': '2022-04-09',
#   'Excerpt': 'パッと検索してなかったので作ってみた',
#   'LastEditedTime': '2022-05-02',
#   'OGImage': None,
#   'PageId': 'a17a8045-fc7f-4873-ab8c-ab4ab659329b',
#   'Rank': 1,
#   'Slug': 'flask',
#   'Tags': ['maintenance', 'programing', 'notion'],
#   'Title': 'flaskでnotionを利用したblog'},
#  {'Date': '2022-03-02',
#   'Excerpt': 'りんく',
#   'LastEditedTime': '2022-03-03',
#   'OGImage': None,
#   'PageId': '5eb2d357-0c96-4d28-9edf-61750be093f8',
#   'Rank': 1,
#   'Slug': 'ameblo',
#   'Tags': ['お金系', 'Diary'],
#   'Title': 'アメブロからリンク'},
#  {'Date': '2022-01-28',
#   'Excerpt': 'あるかな…',
#   'LastEditedTime': '2022-04-29',
#   'OGImage': None,
#   'PageId': '2417d226-f436-4dd1-a57f-7835675df6a6',
#   'Rank': 1,
#   'Slug': 'idare',
#   'Tags': ['お金系'],
#   'Title': 'idareの使い道'},
#  {'Date': '2022-01-01',
#   'Excerpt': 'notion-blog-nextjs',
#   'LastEditedTime': '2022-01-10',
#   'OGImage': None,
#   'PageId': 'e0b60596-e47c-431a-baa7-e954fa464478',
#   'Rank': None,
#   'Slug': 'nextjs',
#   'Tags': ['maintenance'],
#   'Title': '別のnotion-apiを使ったものを発見'},
#  {'Date': '2021-12-30',
#   'Excerpt': '書きかけです',
#   'LastEditedTime': '2021-12-30',
#   'OGImage': None,
#   'PageId': '816a443c-a9d1-4119-a5c9-80a5b392f3f1',
#   'Rank': 1,
#   'Slug': 'sshjupy',
#   'Tags': ['programing'],
#   'Title': '自宅PCのjupyterlabを外部から起動する'},
#  {'Date': '2021-12-25',
#   'Excerpt': 'はぴめり',
#   'LastEditedTime': '2022-09-11',
#   'OGImage': 'https://res.cloudinary.com/drnj48esm/image/upload/v1651359317/graph_nviyig.png',
#   'PageId': '8ebc3f32-0504-43ab-9c89-5ea8435078c2',
#   'Rank': 1,
#   'Slug': 'kentikushi',
#   'Tags': ['建築士'],
#   'Title': '一級建築士、独学で合格へ【2021年】'},
#  {'Date': '2021-12-10',
#   'Excerpt': 'いくらしていいのか毎年悩む',
#   'LastEditedTime': '2022-06-22',
#   'OGImage': None,
#   'PageId': '21bd14c5-4bb4-44e3-a432-a27b444187e7',
#   'Rank': 1,
#   'Slug': 'nouzeinoyorokobi2021',
#   'Tags': ['お金系'],
#   'Title': 'ふるさと納税の金額って。。'},
#  {'Date': '2021-11-22',
#   'Excerpt': '見えてる？',
#   'LastEditedTime': '2022-04-03',
#   'OGImage': None,
#   'PageId': '26cca1ed-fd67-4bad-b844-5833a7a3c057',
#   'Rank': None,
#   'Slug': 'test1',
#   'Tags': ['Diary'],
#   'Title': 'テスト'},
#  {'Date': '2021-12-12',
#   'Excerpt': 'memo',
#   'LastEditedTime': '2022-03-10',
#   'OGImage': None,
#   'PageId': '8bb89c06-a504-4215-98c7-fa32763534d1',
#   'Rank': None,
#   'Slug': 'revice',
#   'Tags': ['maintenance'],
#   'Title': 'できることの確認'}]
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T01:48:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'is_toggleable': False,
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '前提',
#                           'text': {'content': '前提', 'link': None},
#                           'type': 'text'}]},
#   'id': '0c76e577-974c-4552-809e-a22728e778a7',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T01:48:00.000Z',
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T01:48:00.000Z',
#   'has_children': False,
#   'id': '24e0c21b-f03d-4338-8cc9-e751c0f30403',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T01:49:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '今まで主流だったaupay-revolutでポイントがつかなくなったことを踏まえ、ケースごとの決済方法を考え直します。旅行好きとしては、ホテル予約でも使えるrevolutは大事。',
#                           'text': {'content': '今まで主流だったaupay-revolutでポイントがつかなくなったことを踏まえ、ケースごとの決済方法を考え直します。旅行好きとしては、ホテル予約でも使えるrevolutは大事。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T01:50:00.000Z',
#   'has_children': False,
#   'id': '73717cfe-417b-420d-8953-eb1841721267',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:24:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '街中リアルクレカ',
#                                    'text': {'content': '街中リアルクレカ',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:24:00.000Z',
#   'has_children': False,
#   'id': '5e0ab23f-12d1-4941-aaeb-7bf29c505ca8',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:24:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '電子マネー',
#                                    'text': {'content': '電子マネー', 'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T01:50:00.000Z',
#   'has_children': False,
#   'id': 'adcbd923-1fd0-4801-a18a-298827c2432d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T01:50:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'インターネット決済',
#                                    'text': {'content': 'インターネット決済',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T01:50:00.000Z',
#   'has_children': False,
#   'id': 'c1b50122-2825-4d2d-a613-0644a8f6c582',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T01:51:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'プリペイドカードNGの場面（携帯料金、ホテル予約など）',
#                                    'text': {'content': 'プリペイドカードNGの場面（携帯料金、ホテル予約など）',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T02:52:00.000Z',
#   'has_children': False,
#   'id': 'd23256bc-9873-4f92-8592-c541a93be2d5',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:24:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ちなみにクレジットカードは特段なければ、NLゴールドの2%（リボ付き）を基準に考えます。',
#                           'text': {'content': 'ちなみにクレジットカードは特段なければ、NLゴールドの2%（リボ付き）を基準に考えます。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:43:00.000Z',
#   'has_children': False,
#   'id': '011a7af1-9397-4fd5-b709-3154f14110a3',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:43:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '結論から言うと、見るべきところのあまりない記事になってしまった。',
#                           'text': {'content': '結論から言うと、見るべきところのあまりない記事になってしまった。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T02:50:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'is_toggleable': False,
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '街中リアルクレカ',
#                           'text': {'content': '街中リアルクレカ', 'link': None},
#                           'type': 'text'}]},
#   'id': 'e405ac34-850a-4481-aafd-637bbd16e26a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T02:51:00.000Z',
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T02:51:00.000Z',
#   'has_children': False,
#   'id': 'ca3e9a50-3c24-4503-871b-0aa887ad9f1d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T02:51:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'やっぱり街中ではリアルクレカが必要になることが多いです。',
#                           'text': {'content': 'やっぱり街中ではリアルクレカが必要になることが多いです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T02:51:00.000Z',
#   'has_children': False,
#   'id': '1ecb8740-a4fc-4c60-8c2f-6880937b0c42',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '＜１０月まで＞3%',
#                           'text': {'content': '＜１０月まで＞3%', 'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T02:51:00.000Z',
#   'has_children': False,
#   'id': '91a6846d-67cd-4421-b2f7-83f56544401c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→auプリペ0.5%',
#                           'text': {'content': 'クレカ2%→auプリペ0.5%', 'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '(ここがなくなる)',
#                           'text': {'content': '(ここがなくなる)', 'link': None},
#                           'type': 'text'},
#                          {'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '→revolut0%→softbankカード0.5%',
#                           'text': {'content': '→revolut0%→softbankカード0.5%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:05:00.000Z',
#   'has_children': False,
#   'id': '2016e852-731e-40ea-8349-698179e39f46',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'これが基本でしたが、ダメになるので考察',
#                           'text': {'content': 'これが基本でしたが、ダメになるので考察',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:15:00.000Z',
#   'has_children': False,
#   'id': 'f7757954-46bb-4c3b-aaec-54c631f34786',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:15:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '案１：2.7%',
#                                    'text': {'content': '案１：2.7%', 'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:07:00.000Z',
#   'has_children': False,
#   'id': '3da74fa2-abc4-462c-a9a4-8ba1e7793559',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:11:00.000Z',
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:07:00.000Z',
#   'has_children': False,
#   'id': '96064f37-cf93-4cdc-afe3-66d07909f987',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:12:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '単純に意味のなくなったauプリペイドをkyashに置き換え。ただrevoは引き続き使いそうなので、私はこれかなと。kyash5万円までなので大体toyotawalletで消えて案２と還元率は実質変わらない。',
#                           'text': {'content': '単純に意味のなくなったauプリペイドをkyashに置き換え。ただrevoは引き続き使いそうなので、私はこれかなと。kyash5万円までなので大体toyotawalletで消えて案２と還元率は実質変わらない。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:11:00.000Z',
#   'has_children': False,
#   'id': 'd9cfc88d-4286-46aa-9e0d-3684b1d5c0eb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:12:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→kyash0.2%→revolut0%→softbankカード0.5%',
#                           'text': {'content': 'クレカ2%→kyash0.2%→revolut0%→softbankカード0.5%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:11:00.000Z',
#   'has_children': False,
#   'id': '4cc0da37-37a8-48da-8ebb-194266968c6a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:11:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': '案2：2.5%',
#                                    'text': {'content': '案2：2.5%', 'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:11:00.000Z',
#   'has_children': False,
#   'id': 'ba18ae60-c7c4-4391-a1ad-6a90a0aeaf4e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:11:00.000Z',
#   'object': 'block',
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:13:00.000Z',
#   'has_children': False,
#   'id': 'fc96ee89-0d58-41b0-b36a-ea4ba15ddb0b',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:17:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'エポスゴールド1.5%+1%→6gram（mixiM）',
#                           'text': {'content': 'エポスゴールド1.5%+1%→6gram（mixiM）',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:14:00.000Z',
#   'has_children': False,
#   'id': 'da745fed-9a28-4da3-9bcc-19f824a6268f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:35:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '私はリアルカード持ってないです。ちなみに家族いないのでわからないですが家族がいると追加されるポイントもあって2.7%くらいまでは行くらしい。リボも不要。ただ積立してると年40万しか使えないのでメインとしては少ないかも。',
#                           'text': {'content': '私はリアルカード持ってないです。ちなみに家族いないのでわからないですが家族がいると追加されるポイントもあって2.7%くらいまでは行くらしい。リボも不要。ただ積立してると年40万しか使えないのでメインとしては少ないかも。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:15:00.000Z',
#   'has_children': False,
#   'id': 'db0ff398-300d-41b1-8f89-7a0d7dc1431e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:35:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '加えて、今と変わらず下のどれでもいけそう。',
#                           'text': {'content': '加えて、今と変わらず下のどれでもいけそう。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:10:00.000Z',
#   'has_children': False,
#   'id': 'b0afd2c6-f7a8-4d74-9fd9-1a93694f8920',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:10:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→auプリペ0%→revolut0%→softbankカード0.5%',
#                           'text': {'content': 'クレカ2%→auプリペ0%→revolut0%→softbankカード0.5%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:07:00.000Z',
#   'has_children': False,
#   'id': '8fd8a534-34c5-417c-8d17-d91e0365ac31',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:08:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→revolut0%→softbankカード0.5%',
#                           'text': {'content': 'クレカ2%→revolut0%→softbankカード0.5%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-10-13T03:07:00.000Z',
#   'has_children': False,
#   'id': '4bebee0f-a2ae-4d46-b686-381ad1078b0c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-10-13T03:08:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→auプリペ0.5%',
#                           'text': {'content': 'クレカ2%→auプリペ0.5%', 'link': None},
#                           'type': 'text'}]},
#   'parent': {'page_id': '531c184d-0ffe-44ee-a71a-cc957a78af97',
#              'type': 'page_id'},
# ...
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→kyash0.2%→TW1%→suica/ID',
#                           'text': {'content': 'クレカ2%→kyash0.2%→TW1%→suica/ID',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'f34918d8-bbbc-4d04-88de-6793bfd98ca5',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '楽天証券用',
#                           'text': {'content': '楽天証券用', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '1fa2fd0a-386a-43a1-b8fe-6497622392de',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ちなみに楽天キャッシュにもauプリぺ使えなくなるのでシンプルな感じ',
#                           'text': {'content': 'ちなみに楽天キャッシュにもauプリぺ使えなくなるのでシンプルな感じ',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'adac4e13-6e76-4df0-b3bb-c7880b6c7db3',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→nanaco→楽天キャッシュ',
#                           'text': {'content': 'クレカ2%→nanaco→楽天キャッシュ',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'b094cd8b-c1c2-45f0-a5e9-738f2e7fcf2e',
#   'RichTexts': {'color': 'default',
#                 'is_toggleable': False,
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'インターネット決済',
#                           'text': {'content': 'インターネット決済', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': 'f3b815ee-9e98-4350-aace-92994b99abd3',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '同上です',
#                           'text': {'content': '同上です', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '90605684-0902-4f23-b7de-5f6bdfcef6a6',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '案：3.2%',
#                           'text': {'content': '案：3.2%', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '07901131-8622-4802-8eb8-7a24ce455f25',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→kyash0.2%→TW1%',
#                           'text': {'content': 'クレカ2%→kyash0.2%→TW1%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'd9bd2d8c-c587-4256-a570-323572bf2d96',
#   'RichTexts': {'color': 'default',
#                 'is_toggleable': False,
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'プリペイドカードNGの場面',
#                           'text': {'content': 'プリペイドカードNGの場面', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '5c406d00-a3c2-44d7-aa64-61e09125e7e1',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'クレカ2%→kyash0.2%→revolut0%',
#                           'text': {'content': 'クレカ2%→kyash0.2%→revolut0%',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'f3297a47-6fde-4166-8ee8-1a0d3518cc00',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ホテル予約など。普通にクレカ使うのとほぼ変わらない。。この結論が嫌でこの記事書き出して考えたんですが、なさそうです。。やはりrevolutが特別なんですね。',
#                           'text': {'content': 'ホテル予約など。普通にクレカ使うのとほぼ変わらない。。この結論が嫌でこの記事書き出して考えたんですが、なさそうです。。やはりrevolutが特別なんですね。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '23d9ca53-df4b-4c08-82ec-498a5640b32b',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '以下一応確認した内容。',
#                           'text': {'content': '以下一応確認した内容。', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '6be0e50f-34b9-427c-8a7b-15d8de2d7e37',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'mixiMは決済できるらしい。旅行代理店ってじゃらんとかも入るよね。ただ公共料金や携帯はNG。',
#                           'text': {'content': 'mixiMは決済できるらしい。旅行代理店ってじゃらんとかも入るよね。ただ公共料金や携帯はNG。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': 'ded3cc6f-fd0f-4fdc-9e59-55be044e15da',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://support.m.mixi.com/hc/ja/articles/4416136486041-%E3%81%94%E5%88%A9%E7%94%A8%E5%8F%AF%E8%83%BD%E3%81%AA%E3%81%8A%E5%BA%97%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6',
#                           'plain_text': 'https://support.m.mixi.com/hc/ja/articles/4416136486041-ご利用可能なお店について',
#                           'text': {'content': 'https://support.m.mixi.com/hc/ja/articles/4416136486041-ご利用可能なお店について',
#                                    'link': {'url': 'https://support.m.mixi.com/hc/ja/articles/4416136486041-%E3%81%94%E5%88%A9%E7%94%A8%E5%8F%AF%E8%83%BD%E3%81%AA%E3%81%8A%E5%BA%97%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6'}},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '9fedf8c7-718d-4782-9924-0763971d7ccd',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'B43はダメそう。',
#                           'text': {'content': 'B43はダメそう。', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': 'ef8e5c34-3f07-468a-b55d-8105adbf0e01',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://support.b43.jp/hc/ja/articles/900000517623-B-43%E3%82%AB%E3%83%BC%E3%83%89%E3%81%8C%E4%BD%BF%E3%81%88%E3%81%AA%E3%81%84%E3%81%8A%E5%BA%97%E3%81%AF%E3%81%82%E3%82%8A%E3%81%BE%E3%81%99%E3%81%8B-',
#                           'plain_text': 'https://support.b43.jp/hc/ja/articles/900000517623-B-43カードが使えないお店はありますか-',
#                           'text': {'content': 'https://support.b43.jp/hc/ja/articles/900000517623-B-43カードが使えないお店はありますか-',
#                                    'link': {'url': 'https://support.b43.jp/hc/ja/articles/900000517623-B-43%E3%82%AB%E3%83%BC%E3%83%89%E3%81%8C%E4%BD%BF%E3%81%88%E3%81%AA%E3%81%84%E3%81%8A%E5%BA%97%E3%81%AF%E3%81%82%E3%82%8A%E3%81%BE%E3%81%99%E3%81%8B-'}},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '733a5748-607e-4c30-a4e0-74366436ce8f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'Kyashも同じく。',
#                           'text': {'content': 'Kyashも同じく。', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '39040e7d-58b0-4580-83fd-b6873bd63e11',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': 'https://support.kyash.co/hc/ja/articles/115004500767-%E5%88%A9%E7%94%A8%E3%81%A7%E3%81%8D%E3%81%AA%E3%81%84Visa%E5%8A%A0%E7%9B%9F%E5%BA%97%E3%81%8C%E3%81%82%E3%82%8A%E3%81%BE%E3%81%97%E3%81%9F',
#                           'plain_text': 'https://support.kyash.co/hc/ja/articles/115004500767-利用できないVisa加盟店がありました',
#                           'text': {'content': 'https://support.kyash.co/hc/ja/articles/115004500767-利用できないVisa加盟店がありました',
#                                    'link': {'url': 'https://support.kyash.co/hc/ja/articles/115004500767-%E5%88%A9%E7%94%A8%E3%81%A7%E3%81%8D%E3%81%AA%E3%81%84Visa%E5%8A%A0%E7%9B%9F%E5%BA%97%E3%81%8C%E3%81%82%E3%82%8A%E3%81%BE%E3%81%97%E3%81%9F'}},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'c5e30e56-1759-487f-b60a-5270ad2f94bf',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '7d347102-8055-4347-b179-89436720e09e',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '以上です。revolutへの道はkyashしかないとするとkyashへチャージするクレカを次は考えます。',
#                           'text': {'content': '以上です。revolutへの道はkyashしかないとするとkyashへチャージするクレカを次は考えます。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'}]
