# %%
from flask import Flask, render_template, request, redirect, session, url_for
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    if prop["Published"]["checkbox"]:
        post = {
            "PageId": db["results"][i]["id"],
            "Title": prop["Page"]["title"][0]["plain_text"],
            "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
            "Date": prop["Date"]["date"]["start"],
            "LastEditedTime": db["results"][i]["last_edited_time"][:10],
            "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
            "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
            "OGImage":ogimege[0]["file"]["url"] if len(ogimege)> 0 else None,
            "Rank": prop["Rank"]["number"]}
        tags.extend(post["Tags"])
        posts.append(post)
tags_set=list(set(tags))

# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
def get_title(html):
    """Scrape page title."""
    title = None
    if type(html.title)==str:
        title = html.title.string
    elif html.find("meta", property="og:title"):
        title = html.find("meta", property="og:title").get('content')
    elif html.find("meta", property="twitter:title"):
        title = html.find("meta", property="twitter:title").get('content')
    elif html.find("h1"):
        title = html.find("h1").string
    return title


def get_description(html):
    """Scrape page description."""
    description = None
    if html.find("meta", property="description"):
        description = html.find("meta", property="description").get('content')
    elif html.find("meta", property="og:description"):
        description = html.find("meta", property="og:description").get('content')
    elif html.find("meta", property="twitter:description"):
        description = html.find("meta", property="twitter:description").get('content')
    elif html.find("p"):
        description = html.find("p").contents
    return description


def get_image(html):
    """Scrape share image."""
    image = None
    if html.find("meta", property="image"):
        image = html.find("meta", property="image").get('content')
    elif html.find("meta", property="og:image"):
        image = html.find("meta", property="og:image").get('content')
    elif html.find("meta", property="twitter:image"):
        image = html.find("meta", property="twitter:image").get('content')
    elif html.find("img", src=True):
        image = html.find("img").get('src')
    return image

def generate_preview(url):
    req = requests.get(url, headers)
    html = BeautifulSoup(req.content, 'html.parser')
    meta_data = {
       'title': get_title(html),
       'description': get_description(html),
       'image': get_image(html),
    }
    return meta_data


def make_page(p):
    item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }

        elif item_type in ["link_preview","bookmark","embed"]:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Url":item[i][item_type]["url"],
                "LinkPreview": generate_preview(item[i][item_type]["url"]),
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

# %%
app = Flask(__name__)
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/top','Blog':'/','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/top")
def index():
    return render_template("index.html",labellist=labellist,tags=tags_set)

@app.route("/", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    return render_template("blog.html",labellist=labellist,posts=posts,tags=tags_set,tagname=0)

@app.route("/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    return render_template("blog.html",labellist=labellist,posts=tag_page,tags=tags_set,tagname=Tag)


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET /static/css/blog.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2022 22:37:12] "GET /static/css/blog-parts.module.css HTTP/1.1" 200 -
# [2022-05-01 22:37:13,211] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-efea72514003>", line 24, in page
#     blocks=make_page(page_num)
# UnboundLocalError: local variable 'page_num' referenced before assignment
# 127.0.0.1 - - [01/May/2022 22:37:13] "GET /favicon.ico HTTP/1.1" 500 -
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T21:53:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'なんでも無料でできると嬉しい...',
#                           'text': {'content': 'なんでも無料でできると嬉しい...',
#                                    'link': None},
#                           'type': 'text'}]},
#   'id': '280859fc-57fe-48d2-a43a-aeb8473b2df2',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T21:56:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T21:54:00.000Z',
#   'has_children': False,
#   'id': '350fd9a4-b50d-4567-b298-21d00b1efb50',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '私はプログラマーではないのですが、ブログというか自分のサイトを作りたく、アメブロから始まり、notionを使った自作ブログなどいくつか試しています。ただやっぱりかっこいいサイトを初心者が作るとなるとwordpressを使うというのが今の主流な気がします。cssとか触らなくていいのがとても嬉しいというのはnotionブログを作ったときに痛感しました。ただwordpressはレンタルサーバーが必須と聞いていて、有料だと思い込んでいました。そんな中、herokuを使えば無料でできるかも、という話を耳にし、やってみました。類似の記事はみましたが時期が古かったので。自分へのメモと初心者仲間への共有のため記事にします。2022年4月末です、GWの暇つぶしです。',
#                           'text': {'content': '私はプログラマーではないのですが、ブログというか自分のサイトを作りたく、アメブロから始まり、notionを使った自作ブログなどいくつか試しています。ただやっぱりかっこいいサイトを初心者が作るとなるとwordpressを使うというのが今の主流な気がします。cssとか触らなくていいのがとても嬉しいというのはnotionブログを作ったときに痛感しました。ただwordpressはレンタルサーバーが必須と聞いていて、有料だと思い込んでいました。そんな中、herokuを使えば無料でできるかも、という話を耳にし、やってみました。類似の記事はみましたが時期が古かったので。自分へのメモと初心者仲間への共有のため記事にします。2022年4月末です、GWの暇つぶしです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:33:00.000Z',
#   'has_children': False,
#   'id': 'c974f129-1bd7-4b52-a40e-deb970bb243a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '結論としてはできましたが、後で触れる5MBのデータベースでどれくらい記事がかけるのかという将来の不安と、いろいろいじっているとしばしばデータベースとの接続が切れてしまうのでストレスはありますが、無料でできる気持ちよさで私は幸せになれました。notionをデータベースとして使えるといいのだけどまだそうした先人も見つけられないし、私の能力もありません...',
#                           'text': {'content': '結論としてはできましたが、後で触れる5MBのデータベースでどれくらい記事がかけるのかという将来の不安と、いろいろいじっているとしばしばデータベースとの接続が切れてしまうのでストレスはありますが、無料でできる気持ちよさで私は幸せになれました。notionをデータベースとして使えるといいのだけどまだそうした先人も見つけられないし、私の能力もありません...',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T21:58:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '前提として',
#                           'text': {'content': '前提として', 'link': None},
#                           'type': 'text'}]},
#   'id': '1850c409-64de-42b3-9e96-2a43e66e7964',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T21:58:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T21:58:00.000Z',
#   'has_children': False,
#   'id': '1c3f25c3-f634-41dd-9cb9-428fc07beae5',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:00:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・私はコピペでコードを打つのには抵抗はありませんが、理解はすごく浅いです。',
#                           'text': {'content': '・私はコピペでコードを打つのには抵抗はありませんが、理解はすごく浅いです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:00:00.000Z',
#   'has_children': False,
#   'id': '4a579882-8412-4ea5-97d5-3a3e6aa62e05',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:01:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・既存のブログの移管ではなく、新設です。（なので後で触れますがDBの容量が少ないことは一旦問題にしません。）',
#                           'text': {'content': '・既存のブログの移管ではなく、新設です。（なので後で触れますがDBの容量が少ないことは一旦問題にしません。）',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:01:00.000Z',
#   'has_children': False,
#   'id': '525565df-7d00-4f8b-a809-15da7e34d9c6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:03:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・自分のサイトを始めたいと書きましたが、継続するかは未定なので拡張性とかは気にしていません。また、続けるか不明なので、無料がいいです。',
#                           'text': {'content': '・自分のサイトを始めたいと書きましたが、継続するかは未定なので拡張性とかは気にしていません。また、続けるか不明なので、無料がいいです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:26:00.000Z',
#   'has_children': False,
#   'id': 'bb7ff469-ccaf-433f-823f-6a73d7b49c08',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:27:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・初心者といいつつ、gitだとかは使える環境です。',
#                           'text': {'content': '・初心者といいつつ、gitだとかは使える環境です。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:02:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '実際に使ったサービス',
#                           'text': {'content': '実際に使ったサービス', 'link': None},
#                           'type': 'text'}]},
#   'id': '5f01f88e-ce29-4d00-95c6-350fd805a9b1',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:03:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:03:00.000Z',
#   'has_children': False,
#   'id': 'e287d9aa-c3e4-414f-a9c1-b808340834cf',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:05:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・wordpress\u3000メインとなるサービス、記事書いたりするもの',
#                           'text': {'content': '・wordpress\u3000'
#                                               'メインとなるサービス、記事書いたりするもの',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:03:00.000Z',
#   'has_children': False,
#   'id': '3a0c2315-2558-4971-82cc-bc89a3703011',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:05:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・heroku\u3000ワードプレスを動作させる場所的なイメージ',
#                           'text': {'content': '・heroku\u3000'
#                                               'ワードプレスを動作させる場所的なイメージ',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:04:00.000Z',
#   'has_children': False,
#   'id': '6090860f-6a7a-4bab-9684-74ae7b9f6a74',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:05:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・cloudinary\u3000画像を保存する場所',
#                           'text': {'content': '・cloudinary\u3000画像を保存する場所',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:09:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'Step1：wordpress-herokuのダウンロード',
#                           'text': {'content': 'Step1：wordpress-herokuのダウンロード',
#                                    'link': None},
#                           'type': 'text'}]},
#   'id': '85b20371-f60f-4712-9ef8-3f7721558148',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:10:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:10:00.000Z',
#   'has_children': False,
#   'id': '5198bfb3-9aa6-4b93-8a67-8dad708a3372',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:11:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '先に結論として、今回の作業を大体やってくれる先人が作ってくださったものがあります。',
#                           'text': {'content': '先に結論として、今回の作業を大体やってくれる先人が作ってくださったものがあります。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:11:00.000Z',
#   'has_children': False,
#   'id': '254748a4-cb1b-49bb-94a1-374328ced97b',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:11:00.000Z',
#   'link_preview': {'url': 'https://github.com/PhilippHeuer/wordpress-heroku'},
#   'object': 'block',
#   'type': 'link_preview'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:11:00.000Z',
#   'has_children': False,
#   'id': '6188ba4a-2b80-4e6b-b338-0611335bd304',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:13:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'なのでここからはこちらの方のwikiに説明があります。',
#                           'text': {'content': 'なのでここからはこちらの方のwikiに説明があります。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:13:00.000Z',
#   'has_children': False,
#   'id': '1881ea91-e731-44fa-ab18-0548cc134deb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:15:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'まず、wordpressはPHPという言語で動いているそうで、このPHPのパッケージマネージャー?であるcomposerをダウンロードしました。macを使っているので',
#                           'text': {'content': 'まず、wordpressはPHPという言語で動いているそうで、このPHPのパッケージマネージャー?であるcomposerをダウンロードしました。macを使っているので',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'brew install composer',
#                      'text': {'content': 'brew install composer', 'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:16:00.000Z',
#   'has_children': False,
#   'id': 'caf5c7d4-ae81-4e76-91b0-3c959a259b8b',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:16:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:15:00.000Z',
#   'has_children': False,
#   'id': '2646f9d5-3873-4cab-a0cd-ce0da5ff176f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:18:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ここを適当にやったのが後で問題になる気もしますが、この作業で2022年4月現在、Composer '
#                                         'version 2.3.5が入ります。上記の先人のものはversion '
#                                         '1.15あたりを想定しているようで後にエラーとの戦いになります。',
#                           'text': {'content': 'ここを適当にやったのが後で問題になる気もしますが、この作業で2022年4月現在、Composer '
#                                               'version '
#                                               '2.3.5が入ります。上記の先人のものはversion '
#                                               '1.15あたりを想定しているようで後にエラーとの戦いになります。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:18:00.000Z',
#   'has_children': False,
#   'id': '23f87e4f-3e41-42f5-b04e-942524586061',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:38:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '戦いの結果としてですが、上記先人のgithubのpull '
#                                         'requestに2021年時点のものに更新されているものがあり、こちらを使いました。',
#                           'text': {'content': '戦いの結果としてですが、上記先人のgithubのpull '
#                                               'requestに2021年時点のものに更新されているものがあり、こちらを使いました。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:20:00.000Z',
#   'has_children': False,
#   'id': 'da96cfe0-ef90-4f29-9c07-db0b8c01838f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:20:00.000Z',
#   'link_preview': {'url': 'https://github.com/PhilippHeuer/wordpress-heroku/pull/46'},
#   'object': 'block',
#   'type': 'link_preview'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:20:00.000Z',
#   'has_children': False,
#   'id': '30d472fe-6248-4924-a42c-0d423b79660a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:29:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '具体的には適当な自分のPCフォルダにて以下を打ちます。ここからは私はVScodeというアプリ上で操作しています。完全に初心者の方はGitとVScodeをインストールして（詳細略）、自分のPCの書類にwordpressというフォルダを作って、VScodeの「フォルダーを開く」からさっき作ったwordpressというフォルダを開いて、そこで「新しいターミナルを開く」をして以下のコードを打つのかなと思います（ここは想像しただけなので上手くいくかはわかりません）。',
#                           'text': {'content': '具体的には適当な自分のPCフォルダにて以下を打ちます。ここからは私はVScodeというアプリ上で操作しています。完全に初心者の方はGitとVScodeをインストールして（詳細略）、自分のPCの書類にwordpressというフォルダを作って、VScodeの「フォルダーを開く」からさっき作ったwordpressというフォルダを開いて、そこで「新しいターミナルを開く」をして以下のコードを打つのかなと思います（ここは想像しただけなので上手くいくかはわかりません）。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'git clone '
#                                    'https://github.com/ptahdunbar/wordpress-heroku.git',
#                      'text': {'content': 'git clone '
#                                          'https://github.com/ptahdunbar/wordpress-heroku.git',
#                               'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:21:00.000Z',
#   'has_children': False,
#   'id': 'f02f3f31-432f-4b6d-8a96-4cf8d32f8fff',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:38:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:38:00.000Z',
#   'has_children': False,
#   'id': '13217146-6d56-4125-8c7f-6dc2e2fb9f0a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:39:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'また上記pull '
#                                         'requestのやりとりを見ると修正版がmainになっていないようなので、次を打ちました。',
#                           'text': {'content': 'また上記pull '
#                                               'requestのやりとりを見ると修正版がmainになっていないようなので、次を打ちました。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'git merge develop',
#                      'text': {'content': 'git merge develop', 'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:39:00.000Z',
#   'has_children': False,
#   'id': '3d49d67f-0fad-4a1f-879e-9ece7fe0e751',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:39:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:39:00.000Z',
#   'has_children': False,
#   'id': '1f826bf5-0306-4552-ae6c-df2c6661e676',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:47:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '次にcomposer.json（要は今回使う動作のために必要な先人の作ったライブラリをまとめたもの？）を修正します。',
#                           'text': {'content': '次にcomposer.json（要は今回使う動作のために必要な先人の作ったライブラリをまとめたもの？）を修正します。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:41:00.000Z',
#   'has_children': False,
#   'id': 'b3adccad-2dcd-417b-b153-fa04d4d59980',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:41:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '具体的には２ヶ所',
#                           'text': {'content': '具体的には２ヶ所', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:42:00.000Z',
#   'has_children': False,
#   'id': '7bfbb312-3f63-4916-87f7-b40b3ef1c56e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:45:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・右側の数字4.0.12になっているかと思いますが変えました',
#                           'text': {'content': '・右側の数字4.0.12になっているかと思いますが変えました',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': '"wpackagist-plugin/all-in-one-seo-pack":"4.2.0"',
#                      'text': {'content': '"wpackagist-plugin/all-in-one-seo-pack":"4.2.0"',
#                               'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:45:00.000Z',
#   'has_children': False,
#   'id': '9312c8e9-8bcc-487c-9c9d-16e438fe2b54',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:45:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:42:00.000Z',
#   'has_children': False,
#   'id': '6b38696f-1aad-4289-9322-292353c19e80',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:04:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '・以下のプラグインはサービス終了しているようです。おそらく何かあった時にメールを送るためのもの？私は利用シーンが想像できないのでシンプルに削除しました。離れた場所にありますが探して削除。',
#                           'text': {'content': '・以下のプラグインはサービス終了しているようです。おそらく何かあった時にメールを送るためのもの？私は利用シーンが想像できないのでシンプルに削除しました。離れた場所にありますが探して削除。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': '"wpackagist-plugin/sendgrid-email-delivery-simplified":"1.11.8”\n'
#                                    '"wpackagist-plugin/sendgrid-email-delivery-simplified"',
#                      'text': {'content': '"wpackagist-plugin/sendgrid-email-delivery-simplified":"1.11.8”\n'
#                                          '"wpackagist-plugin/sendgrid-email-delivery-simplified"',
#                               'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:45:00.000Z',
#   'has_children': False,
#   'id': '2ea8aa1d-f3c1-4039-b847-973efb111836',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:03:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-01T13:02:00.000Z',
#   'has_children': False,
#   'id': '09b30181-4434-45f5-bfdc-095c93c13fd6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:04:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ついでに画像無料でを扱うためのプラグインも入れていきます。以下でアカウントを作成',
#                           'text': {'content': 'ついでに画像無料でを扱うためのプラグインも入れていきます。以下でアカウントを作成',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bookmark': {'caption': [], 'url': 'https://cloudinary.com/'},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-01T13:02:00.000Z',
#   'has_children': False,
#   'id': '938847fa-db12-48d9-9e05-1a0d178877f4',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:04:00.000Z',
#   'object': 'block',
#   'type': 'bookmark'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-01T13:04:00.000Z',
#   'has_children': False,
#   'id': '14710757-0e0a-460b-8452-e11d5b45320c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:04:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'プラグインをcomposer.jsonに入れます。',
#                           'text': {'content': 'プラグインをcomposer.jsonに入れます。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': '#以下のrequireの中のどこかに\n'
#                                    '"require": {\n'
#                                    '〜〜〜\n'
#                                    '"wpackagist-plugin/cloudinary-image-management-and-manipulation-in-the-cloud-cdn":"3.0.3",\n'
#                                    '〜〜〜\n'
#                                    '}\n'
#                                    '#もう一ヶ所 以下の中にも\n'
#                                    '"web/app/plugins/{$name}/": [\n'
#                                    '〜〜〜\n'
#                                    '"wpackagist-plugin/cloudinary-image-management-and-manipulation-in-the-cloud-cdn"\n'
#                                    '〜〜〜\n'
#                                    ']\n',
#                      'text': {'content': '#以下のrequireの中のどこかに\n'
#                                          '"require": {\n'
#                                          '〜〜〜\n'
#                                          '"wpackagist-plugin/cloudinary-image-management-and-manipulation-in-the-cloud-cdn":"3.0.3",\n'
#                                          '〜〜〜\n'
#                                          '}\n'
#                                          '#もう一ヶ所 以下の中にも\n'
#                                          '"web/app/plugins/{$name}/": [\n'
#                                          '〜〜〜\n'
#                                          '"wpackagist-plugin/cloudinary-image-management-and-manipulation-in-the-cloud-cdn"\n'
#                                          '〜〜〜\n'
#                                          ']\n',
#                               'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-05-01T13:05:00.000Z',
#   'has_children': False,
#   'id': '6a264aab-59ea-45cf-8e86-d6985fc82698',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:07:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:43:00.000Z',
#   'has_children': False,
#   'id': '5ecc3763-6a0f-472c-8c95-f415069cea77',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:04:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ここまでしたら上手くいくはずなので、以下を入れて必要なものをインストールします。',
#                           'text': {'content': 'ここまでしたら上手くいくはずなので、以下を入れて必要なものをインストールします。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'composer install',
#                      'text': {'content': 'composer install', 'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:46:00.000Z',
#   'has_children': False,
#   'id': '2b5ead17-8d85-4377-87bb-1882157ea44c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:46:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:48:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'Step2:herokuの設定',
#                           'text': {'content': 'Step2:herokuの設定', 'link': None},
#                           'type': 'text'}]},
#   'id': 'd29e5a5b-bdc9-4d21-9fd5-6313843a0914',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-04-30T22:49:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-04-30T22:49:00.000Z',
#   'has_children': False,
#   'id': '4469b066-9c7b-44f9-b269-d393e5cde174',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-05-01T13:09:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'まずherokuのアカウントを作ります。（詳細略）できたらログインします。ブラウザ開くので適宜。',
#                           'text': {'content': 'まずherokuのアカウントを作ります。（詳細略）できたらログインします。ブラウザ開くので適宜。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
# ...
#                      'href': None,
#                      'plain_text': '\n'
#                                    'heroku create 適当なアプリ名\u3000#アプリ作成\n'
#                                    'heroku config:set \\\u3000#環境変数\u3000'
#                                    'シークレットはそのままでも動くけど適宜入れ替えるべき\n'
#                                    "    AUTH_KEY='SECRET' \\\n"
#                                    "    SECURE_AUTH_KEY='SECRET' \\\n"
#                                    "    LOGGED_IN_KEY='SECRET' \\\n"
#                                    "    NONCE_KEY='SECRET' \\\n"
#                                    "    AUTH_SALT='SECRET' \\\n"
#                                    "    SECURE_AUTH_SALT='SECRET' \\\n"
#                                    "    LOGGED_IN_SALT='SECRET' \\\n"
#                                    "    NONCE_SALT='SECRET'\n"
#                                    'heroku addons:create jawsdb:kitefin\u3000'
#                                    '#データベースの作成',
#                      'text': {'content': '\n'
#                                          'heroku create 適当なアプリ名\u3000#アプリ作成\n'
#                                          'heroku config:set \\\u3000#環境変数\u3000'
#                                          'シークレットはそのままでも動くけど適宜入れ替えるべき\n'
#                                          "    AUTH_KEY='SECRET' \\\n"
#                                          "    SECURE_AUTH_KEY='SECRET' \\\n"
#                                          "    LOGGED_IN_KEY='SECRET' \\\n"
#                                          "    NONCE_KEY='SECRET' \\\n"
#                                          "    AUTH_SALT='SECRET' \\\n"
#                                          "    SECURE_AUTH_SALT='SECRET' \\\n"
#                                          "    LOGGED_IN_SALT='SECRET' \\\n"
#                                          "    NONCE_SALT='SECRET'\n"
#                                          'heroku addons:create '
#                                          'jawsdb:kitefin\u3000#データベースの作成',
#                               'link': None},
#                      'type': 'text'}]},
#   'Type': 'code'},
#  {'HasChildren': False,
#   'Id': 'd7278014-2d3d-45f0-85c4-1f9f393dd1c2',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'Step3:デプロイ',
#                           'text': {'content': 'Step3:デプロイ', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '51f6fa9d-9c62-45e6-a14b-c0821a1acad5',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '以下のコードを入れます',
#                           'text': {'content': '以下のコードを入れます', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'Caption': [],
#   'HasChildren': False,
#   'Id': 'ad4d5b56-575e-401d-ba3a-17488d3bb32b',
#   'Language': 'python',
#   'Text': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'git push heroku master',
#                      'text': {'content': 'git push heroku master',
#                               'link': None},
#                      'type': 'text'}]},
#   'Type': 'code'},
#  {'HasChildren': False,
#   'Id': '06c89303-c42c-4fc4-9c88-ea01f5d7c171',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'そして開いてみると。。',
#                           'text': {'content': 'そして開いてみると。。', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'Caption': [],
#   'HasChildren': False,
#   'Id': '012b629c-0cf8-4bb2-b95a-6661fb69f6ed',
#   'Language': 'python',
#   'Text': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'heroku open',
#                      'text': {'content': 'heroku open', 'link': None},
#                      'type': 'text'}]},
#   'Type': 'code'},
#  {'HasChildren': False,
#   'Id': 'affea5cc-eedb-4f78-bb62-63be5917c463',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '以上で以下の画面まで行けると思います。',
#                           'text': {'content': '以上で以下の画面まで行けると思います。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '610c460d-e48f-40bc-b7f1-91e5bdc5476b',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ここからは案内の通り、wordpressのアカウント作って記事など書いたりするだけです。',
#                           'text': {'content': 'ここからは案内の通り、wordpressのアカウント作って記事など書いたりするだけです。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '175e9905-f593-4bde-b517-c50baba6ed8b',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'Step4:プラグインの有効化',
#                           'text': {'content': 'Step4:プラグインの有効化', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '8162e314-3464-4ee4-9511-b323346d9c74',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'プラグインはデフォルトだとdeacitiveになっているようなのでacitiveにします。',
#                           'text': {'content': 'プラグインはデフォルトだとdeacitiveになっているようなのでacitiveにします。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '737c52e2-0991-4293-b2fe-b50a2fc06cdb',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'これで完成！ストレスなくとは言えませんが、ブログは作れます。画像はそのまま貼り付けると一時的にしか保存されずに消えてしまうので、cloudinaryのタブにアップロードしてそこからコピーして貼り付けます。（cloudinaryは初回にsign '
#                                         'inが必要ですが簡単なので略）',
#                           'text': {'content': 'これで完成！ストレスなくとは言えませんが、ブログは作れます。画像はそのまま貼り付けると一時的にしか保存されずに消えてしまうので、cloudinaryのタブにアップロードしてそこからコピーして貼り付けます。（cloudinaryは初回にsign '
#                                               'inが必要ですが簡単なので略）',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '5e027f9b-a9c2-46d0-9872-797e4edeabef',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '問題点',
#                           'text': {'content': '問題点', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '3d695e05-6b91-4b55-b0d5-e3775dd21478',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ひとえにデータベースとの接続がしばしば切れるところ。おそらく１時間に3600クエリ分のやりとりをすると接続が切れる。そうするとブログをいじったりできなくなるし、記事も０件扱いになる。この状況でもブログタイトルとかはみれたりするので、そうした情報はデータベース以外で持っているのかな。よくわからない...',
#                           'text': {'content': 'ひとえにデータベースとの接続がしばしば切れるところ。おそらく１時間に3600クエリ分のやりとりをすると接続が切れる。そうするとブログをいじったりできなくなるし、記事も０件扱いになる。この状況でもブログタイトルとかはみれたりするので、そうした情報はデータベース以外で持っているのかな。よくわからない...',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '79c1e8e7-31c2-4a84-9d76-7a3de1c54e92',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '終わりに',
#                           'text': {'content': '終わりに', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '280c9979-f156-4842-b93b-de80859cc860',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'あまり続けられる気がしないが、1日で解決できたので一旦満足。その他wordpressのバージョンを5.7にしたのはarkheというテーマが5.7以上となっていたからでした。',
#                           'text': {'content': 'あまり続けられる気がしないが、1日で解決できたので一旦満足。その他wordpressのバージョンを5.7にしたのはarkheというテーマが5.7以上となっていたからでした。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'e5331660-aa90-4d02-9bbb-09fb9b986fe7',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '完成品',
#                           'text': {'content': '完成品', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '4708d426-1910-4e33-afb4-c02459d48257',
#   'LinkPreview': {'description': 'ゆったり見てね',
#                   'image': 'data:image/svg+xml;utf8,<svg '
#                            'xmlns="http://www.w3.org/2000/svg" width="1024" '
#                            'height="684"><rect width="100%" '
#                            'height="100%"><animate attributeName="fill" '
#                            'values="rgba(153,153,153,0.5);rgba(153,153,153,0.1);rgba(153,153,153,0.5)" '
#                            'dur="2s" repeatCount="indefinite" /></rect></svg>',
#                   'title': 'My lifelog'},
#   'Type': 'bookmark',
#   'Url': 'https://wordpress-notion.herokuapp.com/'}]
# 127.0.0.1 - - [01/May/2022 22:37:20] "GET /static/css/notion-block.module.css HTTP/1.1" 200 -
# [2022-05-01 22:37:21,273] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/ogikensuke/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-efea72514003>", line 24, in page
#     blocks=make_page(page_num)
# UnboundLocalError: local variable 'page_num' referenced before assignment
# 127.0.0.1 - - [01/May/2022 22:37:21] "GET /favicon.ico HTTP/1.1" 500 -
