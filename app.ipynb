# %%
from flask import Flask, render_template, request, redirect, session, url_for,send_from_directory
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    if prop["Page"]["title"][0]["plain_text"]=="biography":
        bio_id=db["results"][i]["id"]
    if prop["Published"]["checkbox"]:
        post = {
            "PageId": db["results"][i]["id"],
            "Title": prop["Page"]["title"][0]["plain_text"],
            "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
            "Date": prop["Date"]["date"]["start"],
            "LastEditedTime": db["results"][i]["last_edited_time"][:10],
            "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
            "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
            "OGImage":ogimege[0]["external"]["url"] if len(ogimege)> 0 else None,
            "Rank": prop["Rank"]["number"]}
        tags.extend(post["Tags"])
        posts.append(post)
tags_set=list(set(tags))

# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
def get_title(html):
    """Scrape page title."""
    title = None
    if type(html.title)==str:
        title = html.title.string
    elif html.find("meta", property="og:title"):
        title = html.find("meta", property="og:title").get('content')
    elif html.find("meta", property="twitter:title"):
        title = html.find("meta", property="twitter:title").get('content')
    elif html.find("h1"):
        title = html.find("h1").string
    return title


def get_description(html):
    """Scrape page description."""
    description = None
    if html.find("meta", property="description"):
        description = html.find("meta", property="description").get('content')
    elif html.find("meta", property="og:description"):
        description = html.find("meta", property="og:description").get('content')
    elif html.find("meta", property="twitter:description"):
        description = html.find("meta", property="twitter:description").get('content')
    elif html.find("p"):
        description = html.find("p").contents
    return description


def get_image(html):
    """Scrape share image."""
    image = None
    if html.find("meta", property="image"):
        image = html.find("meta", property="image").get('content')
    elif html.find("meta", property="og:image"):
        image = html.find("meta", property="og:image").get('content')
    elif html.find("meta", property="twitter:image"):
        image = html.find("meta", property="twitter:image").get('content')
    elif html.find("img", src=True):
        image = html.find("img").get('src')
    return image

def generate_preview(url):
    req = requests.get(url, headers)
    html = BeautifulSoup(req.content, 'html.parser')
    meta_data = {
       'title': get_title(html),
       'description': get_description(html),
       'image': get_image(html),
    }
    return meta_data


def make_page(p):
    if p=="bio":
        item = notion.blocks.children.list(block_id=bio_id)["results"]
    else:
        item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }

        elif item_type in ["link_preview","bookmark","embed"]:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Url":item[i][item_type]["url"],
                "LinkPreview": generate_preview(item[i][item_type]["url"]),
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

def makesitemap():
    import xml.etree.ElementTree as ET

    urls = [
        "https://flasknotionblog.herokuapp.com/",
        "https://flasknotionblog.herokuapp.com/top"
    ]
    for p in range(len(posts)):
        urls.append("https://flasknotionblog.herokuapp.com/"+posts[p]["Slug"])
    urlset = ET.Element('urlset')
    urlset.set("xmlns", "http://www.sitemaps.org/schemas/sitemap/0.9")
    tree = ET.ElementTree(element=urlset)

    for u in range(len(urls)):
        url=urls[u]
        url_element = ET.SubElement(urlset, 'url')
        loc = ET.SubElement(url_element, 'loc')
        loc.text = url
        lastmod = ET.SubElement(url_element, 'lastmod')
        if u<2:
            lastmod.text = "2022-04-01"
        else:
            lastmod.text = posts[u-2]["LastEditedTime"]

    path = './static/sitemap.txt'
    f = open(path, 'w')
    for url in urls:
        f.write(url+"\n")
    f.close()
    tree.write('static/sitemap.xml', encoding='utf-8', xml_declaration=True)
#makesitemap()

# %%
app = Flask(__name__, static_folder='static')
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/top','Blog':'/','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/top")
def index():
    blocks=make_page("bio")
    return render_template("index.html",blocks=blocks,labellist=labellist,tags=tags_set)

@app.route("/", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    blocks=make_page("bio")
    pprint(posts)
    return render_template("blog.html",labellist=labellist,posts=posts,blocks=blocks,tags=tags_set,tagname=0)

@app.route("/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    blocks=make_page("bio")
    return render_template("blog.html",labellist=labellist,posts=tag_page,blocks=blocks,tags=tags_set,tagname=Tag)

@app.route('/robots.txt')
@app.route('/sitemap.xml')
@app.route('/sitemap.txt')
@app.route('/default.jpg')
@app.route('/favicon.ico')
def static_from_root():
    return send_from_directory(app.static_folder, request.path[1:])

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [{'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'import os\nok',
#                      'text': {'content': 'import os\nok', 'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:35:00.000Z',
#   'has_children': False,
#   'id': '2d54374d-f3a1-4574-9762-3342ba21b7e6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-10T17:26:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'bulleted list',
#                                    'text': {'content': 'bulleted list',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:21:00.000Z',
#   'has_children': False,
#   'id': '6e535f36-05fb-41e1-8031-ef787cbda4dc',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': '72302ee4-31be-4d75-81df-c18f1eb7b301',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': True},
#                           'href': None,
#                           'plain_text': '河川',
#                           'text': {'content': '河川', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': 'e2751b89-ccd5-416b-aef1-a32691ed6e64',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '太字',
#                           'text': {'content': '太字', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': '96f03b13-5522-4f55-b818-24ce50b1373f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': True,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'イタリック',
#                           'text': {'content': 'イタリック', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:31:00.000Z',
#   'has_children': False,
#   'id': '9b6f6dfa-17a1-4a28-88d1-319de1e69310',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-07T20:02:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '色はつかないのかな',
#                           'text': {'content': '色はつかないのかな', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:46:00.000Z',
#   'has_children': False,
#   'id': '72ef94fe-0164-46cd-959d-3ceceb8e2996',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:24:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': '引用文ok',
#                       'text': {'content': '引用文ok', 'link': None},
#                       'type': 'text'}]},
#   'type': 'quote'},
#  {'archived': False,
#   'callout': {'color': 'gray_background',
#               'icon': {'emoji': '💡', 'type': 'emoji'},
#               'text': [{'annotations': {'bold': False,
#                                         'code': False,
#                                         'color': 'default',
#                                         'italic': False,
#                                         'strikethrough': False,
#                                         'underline': False},
#                         'href': None,
#                         'plain_text': '大事な発言ok',
#                         'text': {'content': '大事な発言ok', 'link': None},
#                         'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:47:00.000Z',
#   'has_children': False,
#   'id': '29ecd7e6-6b0f-43fe-8345-eede3ee36361',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T15:48:00.000Z',
#   'object': 'block',
#   'type': 'callout'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:48:00.000Z',
#   'has_children': False,
#   'heading_1': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい１',
#                           'text': {'content': '大きい１', 'link': None},
#                           'type': 'text'}]},
#   'id': '14d6647e-b2be-42b1-981d-572efcb61f48',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T15:48:00.000Z',
#   'object': 'block',
#   'type': 'heading_1'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:48:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい２',
#                           'text': {'content': '大きい２', 'link': None},
#                           'type': 'text'}]},
#   'id': '4e11ae42-639e-47d7-88a6-d74262c2ad24',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T15:48:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:48:00.000Z',
#   'has_children': False,
#   'heading_3': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい３',
#                           'text': {'content': '大きい３', 'link': None},
#                           'type': 'text'}]},
#   'id': 'acd5e834-843c-43c9-b6d2-7e408c0c4ecc',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T15:48:00.000Z',
#   'object': 'block',
#   'type': 'heading_3'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:46:00.000Z',
#   'has_children': False,
#   'id': '74da83ef-ccac-46b4-af96-8405d24d57b7',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-01T18:18:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                           'text': {'content': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-03-10T14:29:00.000Z',
#   'has_children': True,
#   'id': '47088e01-b9ad-4db1-a6d6-73dc4441f46a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-03-10T14:30:00.000Z',
#   'object': 'block',
#   'table': {'has_column_header': False,
#             'has_row_header': False,
#             'table_width': 5},
#   'type': 'table'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-01T18:18:00.000Z',
#   'has_children': False,
#   'id': '21cffff4-580e-47cb-9380-1074500febdb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-01T18:18:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'huhu',
#                                    'text': {'content': 'huhu', 'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-01T20:45:00.000Z',
#   'has_children': False,
#   'id': 'a2c7c5ad-92c9-40d4-8b94-f05a9512441f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-01T20:45:00.000Z',
#   'numbered_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'fufu',
#                                    'text': {'content': 'fufu', 'link': None},
#                                    'type': 'text'}]},
#   'object': 'block',
#   'type': 'numbered_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T06:42:00.000Z',
#   'divider': {},
#   'has_children': False,
#   'id': 'bb0b0c91-f6bd-4e30-a4b9-c96e9ddc23da',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T06:42:00.000Z',
#   'object': 'block',
#   'type': 'divider'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:46:00.000Z',
#   'has_children': False,
#   'id': '2e187f07-a167-46d7-a3da-95d06cea9ad5',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:46:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'bookmark',
#                           'text': {'content': 'bookmark', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bookmark': {'caption': [],
#                'url': 'https://qiita.com/takamicii/items/b0d1cc92fd172468fbf3'},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T06:43:00.000Z',
#   'has_children': False,
#   'id': '3088ac8f-f6dc-4105-a7e2-0825d20c3efd',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T06:43:00.000Z',
#   'object': 'block',
#   'type': 'bookmark'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:44:00.000Z',
#   'divider': {},
#   'has_children': False,
#   'id': '581c90b3-ebb8-413c-a32b-7ada36aaa081',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:44:00.000Z',
#   'object': 'block',
#   'type': 'divider'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:46:00.000Z',
#   'has_children': False,
#   'id': 'bfc48b71-9749-44dc-8442-5bb5f3dfc7f4',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:46:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet embed',
#                           'text': {'content': 'tweet embed', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:44:00.000Z',
#   'embed': {'caption': [],
#             'url': 'https://twitter.com/nya_n017/status/1478255713885757440'},
#   'has_children': False,
#   'id': 'bdde25ba-1057-430a-8380-69f468e79843',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:44:00.000Z',
#   'object': 'block',
#   'type': 'embed'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:46:00.000Z',
#   'has_children': False,
#   'id': '0912592d-e072-46c8-90c5-d1bbc8a34879',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:46:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'embed',
#                           'text': {'content': 'embed', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bookmark': {'caption': [], 'url': 'https://teratail.com/questions/30854'},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:45:00.000Z',
#   'has_children': False,
#   'id': '400742b2-3aee-4999-bdd5-fbb9fc84a896',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:45:00.000Z',
#   'object': 'block',
#   'type': 'bookmark'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:47:00.000Z',
#   'has_children': False,
#   'id': '4fdabd3c-57e2-4670-ade0-6cb1ede002bd',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:47:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet bookmark',
#                           'text': {'content': 'tweet bookmark', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'bookmark': {'caption': [],
#                'url': 'https://twitter.com/nya_n017/status/1478255713885757440'},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-04T07:45:00.000Z',
#   'has_children': False,
#   'id': '09abe3bc-d9bf-479c-96c9-116257095c7e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-04T07:45:00.000Z',
#   'object': 'block',
#   'type': 'bookmark'}]
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /revice HTTP/1.1" 200 -
# [{'Caption': [],
#   'HasChildren': False,
#   'Id': '2d54374d-f3a1-4574-9762-3342ba21b7e6',
#   'Language': 'python',
#   'Text': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'import os\nok',
#                      'text': {'content': 'import os\nok', 'link': None},
#                      'type': 'text'}]},
#   'Type': 'code'},
#  {'HasChildren': False,
#   'Id': '6e535f36-05fb-41e1-8031-ef787cbda4dc',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'bulleted list',
#                           'text': {'content': 'bulleted list', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'bulleted_list_item'},
#  {'HasChildren': False,
#   'Id': '72302ee4-31be-4d75-81df-c18f1eb7b301',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': True},
#                           'href': None,
#                           'plain_text': '河川',
#                           'text': {'content': '河川', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'e2751b89-ccd5-416b-aef1-a32691ed6e64',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '太字',
#                           'text': {'content': '太字', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '96f03b13-5522-4f55-b818-24ce50b1373f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': True,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'イタリック',
#                           'text': {'content': 'イタリック', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '9b6f6dfa-17a1-4a28-88d1-319de1e69310',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '色はつかないのかな',
#                           'text': {'content': '色はつかないのかな', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '72ef94fe-0164-46cd-959d-3ceceb8e2996',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': '引用文ok',
#                       'text': {'content': '引用文ok', 'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Icon': '💡',
#   'Id': '29ecd7e6-6b0f-43fe-8345-eede3ee36361',
#   'RichTexts': {'color': 'gray_background',
#                 'icon': {'emoji': '💡', 'type': 'emoji'},
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大事な発言ok',
#                           'text': {'content': '大事な発言ok', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'callout'},
#  {'HasChildren': False,
#   'Id': '14d6647e-b2be-42b1-981d-572efcb61f48',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい１',
#                           'text': {'content': '大きい１', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_1'},
#  {'HasChildren': False,
#   'Id': '4e11ae42-639e-47d7-88a6-d74262c2ad24',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい２',
#                           'text': {'content': '大きい２', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': 'acd5e834-843c-43c9-b6d2-7e408c0c4ecc',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい３',
#                           'text': {'content': '大きい３', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_3'},
#  {'HasChildren': False,
#   'Id': '74da83ef-ccac-46b4-af96-8405d24d57b7',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                           'text': {'content': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': True,
#   'Id': '47088e01-b9ad-4db1-a6d6-73dc4441f46a',
#   'Table': {'HasColumnHeader': False,
#             'HasRowHeader': False,
#             'Rows': [],
#             'TableWidth': 5},
#   'Type': 'table'},
#  {'HasChildren': False,
#   'Id': '21cffff4-580e-47cb-9380-1074500febdb',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'huhu',
#                           'text': {'content': 'huhu', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'numbered_list_item'},
#  {'HasChildren': False,
#   'Id': 'a2c7c5ad-92c9-40d4-8b94-f05a9512441f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'fufu',
#                           'text': {'content': 'fufu', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'numbered_list_item'},
#  {'HasChildren': False,
#   'Id': 'bb0b0c91-f6bd-4e30-a4b9-c96e9ddc23da',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'divider'},
#  {'HasChildren': False,
#   'Id': '2e187f07-a167-46d7-a3da-95d06cea9ad5',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'bookmark',
#                           'text': {'content': 'bookmark', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '3088ac8f-f6dc-4105-a7e2-0825d20c3efd',
#   'LinkPreview': {'description': '\n'
#                                  '\n'
#                                  '【経緯】\n'
#                                  '\n'
#                                  '別プロジェクトで作った機能を一部スピンオフして一つのアプリケーションにしたいと言う要望があったため、アプリケーションを別リポジトリにpushすることとなりました。\n'
#                                  '\n'
#                                  '\n'
#                                  '【準備】\n'
#                                  '\n'
#                                  '取り込み元 https://githu...',
#                   'image': 'https://qiita-user-contents.imgix.net/https%3A%2F%2Fcdn.qiita.com%2Fassets%2Fpublic%2Farticle-ogp-background-9f5428127621718a910c8b63951390ad.png?ixlib=rb-4.0.0&w=1200&mark64=aHR0cHM6Ly9xaWl0YS11c2VyLWNvbnRlbnRzLmltZ2l4Lm5ldC9-&mark-x=142&mark-y=112&blend64=aHR0cHM6Ly9xaWl0YS11c2VyLWNvbnRlbnRzLmltZ2l4Lm5ldC9-dGV4dD9peGxpYj1yYi00LjAuMCZ3PTYxNiZ0eHQ9JTQwdGFrYW1pY2lpJnR4dC1jb2xvcj0lMjMyMTIxMjEmdHh0LWZvbnQ9SGlyYWdpbm8lMjBTYW5zJTIwVzYmdHh0LXNpemU9MzYmdHh0LWFsaWduPWxlZnQlMkN0b3Amcz05ZTVhNWE2OTBjYjFiNGQ0OGVjOTM3ODZmNDdkYWM3NA&blend-x=142&blend-y=491&blend-mode=normal&s=2c1a4a02f24c2cd5a976755e17b0ca47',
#                   'title': 'GitHub 別リポジトリに push する方法 - Qiita'},
#   'Type': 'bookmark',
#   'Url': 'https://qiita.com/takamicii/items/b0d1cc92fd172468fbf3'},
#  {'HasChildren': False,
#   'Id': '581c90b3-ebb8-413c-a32b-7ada36aaa081',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'divider'},
#  {'HasChildren': False,
#   'Id': 'bfc48b71-9749-44dc-8442-5bb5f3dfc7f4',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet embed',
#                           'text': {'content': 'tweet embed', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'bdde25ba-1057-430a-8380-69f468e79843',
#   'LinkPreview': {'description': ['We’ve detected that JavaScript is disabled '
#                                   'in this browser. Please enable JavaScript '
#                                   'or switch to a supported browser to '
#                                   'continue using twitter.com. You can see a '
#                                   'list of supported browsers in our Help '
#                                   'Center.'],
#                   'image': 'https://abs.twimg.com/errors/logo46x38.png',
#                   'title': 'JavaScript is not available.'},
#   'Type': 'embed',
#   'Url': 'https://twitter.com/nya_n017/status/1478255713885757440'},
#  {'HasChildren': False,
#   'Id': '0912592d-e072-46c8-90c5-d1bbc8a34879',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'embed',
#                           'text': {'content': 'embed', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '400742b2-3aee-4999-bdd5-fbb9fc84a896',
#   'LinkPreview': {'description': 'GitHubにてソースコードを管理しており、\r\n'
#                                  'masterから作業ブランチを作成してPullRequestをし、mergeする形で作業しています。\r\n'
#                                  '\r\n'
#                                  'それを踏まえたうえで質問なのですが、\r\n'
#                                  '**',
#                   'image': 'https://teratail.com/img/ogpImages/imgFacebookShare.png',
#                   'title': '【Git】リモートのmasterに合わせたい'},
#   'Type': 'bookmark',
#   'Url': 'https://teratail.com/questions/30854'},
#  {'HasChildren': False,
#   'Id': '4fdabd3c-57e2-4670-ade0-6cb1ede002bd',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet bookmark',
#                           'text': {'content': 'tweet bookmark', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '09abe3bc-d9bf-479c-96c9-116257095c7e',
#   'LinkPreview': {'description': ['We’ve detected that JavaScript is disabled '
#                                   'in this browser. Please enable JavaScript '
#                                   'or switch to a supported browser to '
#                                   'continue using twitter.com. You can see a '
#                                   'list of supported browsers in our Help '
#                                   'Center.'],
#                   'image': 'https://abs.twimg.com/errors/logo46x38.png',
#                   'title': 'JavaScript is not available.'},
#   'Type': 'bookmark',
#   'Url': 'https://twitter.com/nya_n017/status/1478255713885757440'}]
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/notion-block.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/blog.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:57] "GET /static/css/blog-parts.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:54:58] "GET /favicon.ico HTTP/1.1" 200 -
# [{'archived': False,
#   'code': {'caption': [],
#            'language': 'python',
#            'text': [{'annotations': {'bold': False,
#                                      'code': False,
#                                      'color': 'default',
#                                      'italic': False,
#                                      'strikethrough': False,
#                                      'underline': False},
#                      'href': None,
#                      'plain_text': 'import os\nok',
#                      'text': {'content': 'import os\nok', 'link': None},
#                      'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:35:00.000Z',
#   'has_children': False,
#   'id': '2d54374d-f3a1-4574-9762-3342ba21b7e6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-10T17:26:00.000Z',
#   'object': 'block',
#   'type': 'code'},
#  {'archived': False,
#   'bulleted_list_item': {'color': 'default',
#                          'text': [{'annotations': {'bold': False,
#                                                    'code': False,
#                                                    'color': 'default',
#                                                    'italic': False,
#                                                    'strikethrough': False,
#                                                    'underline': False},
#                                    'href': None,
#                                    'plain_text': 'bulleted list',
#                                    'text': {'content': 'bulleted list',
#                                             'link': None},
#                                    'type': 'text'}]},
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:21:00.000Z',
#   'has_children': False,
#   'id': '6e535f36-05fb-41e1-8031-ef787cbda4dc',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'type': 'bulleted_list_item'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': '72302ee4-31be-4d75-81df-c18f1eb7b301',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': True},
#                           'href': None,
#                           'plain_text': '河川',
#                           'text': {'content': '河川', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': 'e2751b89-ccd5-416b-aef1-a32691ed6e64',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '太字',
#                           'text': {'content': '太字', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:22:00.000Z',
#   'has_children': False,
#   'id': '96f03b13-5522-4f55-b818-24ce50b1373f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:22:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': True,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'イタリック',
#                           'text': {'content': 'イタリック', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T16:31:00.000Z',
#   'has_children': False,
#   'id': '9b6f6dfa-17a1-4a28-88d1-319de1e69310',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-07T20:02:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '色はつかないのかな',
#                           'text': {'content': '色はつかないのかな', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2021-12-12T15:46:00.000Z',
#   'has_children': False,
#   'id': '72ef94fe-0164-46cd-959d-3ceceb8e2996',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2021-12-12T16:24:00.000Z',
#   'object': 'block',
#   'quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
# ...
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': True},
#                           'href': None,
#                           'plain_text': '河川',
#                           'text': {'content': '河川', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'e2751b89-ccd5-416b-aef1-a32691ed6e64',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': True,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '太字',
#                           'text': {'content': '太字', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '96f03b13-5522-4f55-b818-24ce50b1373f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': True,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'イタリック',
#                           'text': {'content': 'イタリック', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '9b6f6dfa-17a1-4a28-88d1-319de1e69310',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'red',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '色はつかないのかな',
#                           'text': {'content': '色はつかないのかな', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '72ef94fe-0164-46cd-959d-3ceceb8e2996',
#   'Quote': {'color': 'default',
#             'text': [{'annotations': {'bold': False,
#                                       'code': False,
#                                       'color': 'default',
#                                       'italic': False,
#                                       'strikethrough': False,
#                                       'underline': False},
#                       'href': None,
#                       'plain_text': '引用文ok',
#                       'text': {'content': '引用文ok', 'link': None},
#                       'type': 'text'}]},
#   'Type': 'quote'},
#  {'HasChildren': False,
#   'Icon': '💡',
#   'Id': '29ecd7e6-6b0f-43fe-8345-eede3ee36361',
#   'RichTexts': {'color': 'gray_background',
#                 'icon': {'emoji': '💡', 'type': 'emoji'},
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大事な発言ok',
#                           'text': {'content': '大事な発言ok', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'callout'},
#  {'HasChildren': False,
#   'Id': '14d6647e-b2be-42b1-981d-572efcb61f48',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい１',
#                           'text': {'content': '大きい１', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_1'},
#  {'HasChildren': False,
#   'Id': '4e11ae42-639e-47d7-88a6-d74262c2ad24',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい２',
#                           'text': {'content': '大きい２', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': 'acd5e834-843c-43c9-b6d2-7e408c0c4ecc',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '大きい３',
#                           'text': {'content': '大きい３', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_3'},
#  {'HasChildren': False,
#   'Id': '74da83ef-ccac-46b4-af96-8405d24d57b7',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                           'text': {'content': '本来1>2>3だけど1<2=3に見える。行間は1>2>3で正しい。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': True,
#   'Id': '47088e01-b9ad-4db1-a6d6-73dc4441f46a',
#   'Table': {'HasColumnHeader': False,
#             'HasRowHeader': False,
#             'Rows': [],
#             'TableWidth': 5},
#   'Type': 'table'},
#  {'HasChildren': False,
#   'Id': '21cffff4-580e-47cb-9380-1074500febdb',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'huhu',
#                           'text': {'content': 'huhu', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'numbered_list_item'},
#  {'HasChildren': False,
#   'Id': 'a2c7c5ad-92c9-40d4-8b94-f05a9512441f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'fufu',
#                           'text': {'content': 'fufu', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'numbered_list_item'},
#  {'HasChildren': False,
#   'Id': 'bb0b0c91-f6bd-4e30-a4b9-c96e9ddc23da',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'divider'},
#  {'HasChildren': False,
#   'Id': '2e187f07-a167-46d7-a3da-95d06cea9ad5',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'bookmark',
#                           'text': {'content': 'bookmark', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '3088ac8f-f6dc-4105-a7e2-0825d20c3efd',
#   'LinkPreview': {'description': '\n'
#                                  '\n'
#                                  '【経緯】\n'
#                                  '\n'
#                                  '別プロジェクトで作った機能を一部スピンオフして一つのアプリケーションにしたいと言う要望があったため、アプリケーションを別リポジトリにpushすることとなりました。\n'
#                                  '\n'
#                                  '\n'
#                                  '【準備】\n'
#                                  '\n'
#                                  '取り込み元 https://githu...',
#                   'image': 'https://qiita-user-contents.imgix.net/https%3A%2F%2Fcdn.qiita.com%2Fassets%2Fpublic%2Farticle-ogp-background-9f5428127621718a910c8b63951390ad.png?ixlib=rb-4.0.0&w=1200&mark64=aHR0cHM6Ly9xaWl0YS11c2VyLWNvbnRlbnRzLmltZ2l4Lm5ldC9-&mark-x=142&mark-y=112&blend64=aHR0cHM6Ly9xaWl0YS11c2VyLWNvbnRlbnRzLmltZ2l4Lm5ldC9-dGV4dD9peGxpYj1yYi00LjAuMCZ3PTYxNiZ0eHQ9JTQwdGFrYW1pY2lpJnR4dC1jb2xvcj0lMjMyMTIxMjEmdHh0LWZvbnQ9SGlyYWdpbm8lMjBTYW5zJTIwVzYmdHh0LXNpemU9MzYmdHh0LWFsaWduPWxlZnQlMkN0b3Amcz05ZTVhNWE2OTBjYjFiNGQ0OGVjOTM3ODZmNDdkYWM3NA&blend-x=142&blend-y=491&blend-mode=normal&s=2c1a4a02f24c2cd5a976755e17b0ca47',
#                   'title': 'GitHub 別リポジトリに push する方法 - Qiita'},
#   'Type': 'bookmark',
#   'Url': 'https://qiita.com/takamicii/items/b0d1cc92fd172468fbf3'},
#  {'HasChildren': False,
#   'Id': '581c90b3-ebb8-413c-a32b-7ada36aaa081',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'divider'},
#  {'HasChildren': False,
#   'Id': 'bfc48b71-9749-44dc-8442-5bb5f3dfc7f4',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet embed',
#                           'text': {'content': 'tweet embed', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'bdde25ba-1057-430a-8380-69f468e79843',
#   'LinkPreview': {'description': ['We’ve detected that JavaScript is disabled '
#                                   'in this browser. Please enable JavaScript '
#                                   'or switch to a supported browser to '
#                                   'continue using twitter.com. You can see a '
#                                   'list of supported browsers in our Help '
#                                   'Center.'],
#                   'image': 'https://abs.twimg.com/errors/logo46x38.png',
#                   'title': 'JavaScript is not available.'},
#   'Type': 'embed',
#   'Url': 'https://twitter.com/nya_n017/status/1478255713885757440'},
#  {'HasChildren': False,
#   'Id': '0912592d-e072-46c8-90c5-d1bbc8a34879',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'embed',
#                           'text': {'content': 'embed', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '400742b2-3aee-4999-bdd5-fbb9fc84a896',
#   'LinkPreview': {'description': 'GitHubにてソースコードを管理しており、\r\n'
#                                  'masterから作業ブランチを作成してPullRequestをし、mergeする形で作業しています。\r\n'
#                                  '\r\n'
#                                  'それを踏まえたうえで質問なのですが、\r\n'
#                                  '**',
#                   'image': 'https://teratail.com/img/ogpImages/imgFacebookShare.png',
#                   'title': '【Git】リモートのmasterに合わせたい'},
#   'Type': 'bookmark',
#   'Url': 'https://teratail.com/questions/30854'},
#  {'HasChildren': False,
#   'Id': '4fdabd3c-57e2-4670-ade0-6cb1ede002bd',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'tweet bookmark',
#                           'text': {'content': 'tweet bookmark', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '09abe3bc-d9bf-479c-96c9-116257095c7e',
#   'LinkPreview': {'description': ['We’ve detected that JavaScript is disabled '
#                                   'in this browser. Please enable JavaScript '
#                                   'or switch to a supported browser to '
#                                   'continue using twitter.com. You can see a '
#                                   'list of supported browsers in our Help '
#                                   'Center.'],
#                   'image': 'https://abs.twimg.com/errors/logo46x38.png',
#                   'title': 'JavaScript is not available.'},
#   'Type': 'bookmark',
#   'Url': 'https://twitter.com/nya_n017/status/1478255713885757440'}]
# 127.0.0.1 - - [08/May/2022 00:58:37] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:58:37] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:58:37] "GET /static/css/blog.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:58:37] "GET /static/css/blog-parts.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:58:37] "GET /static/css/notion-block.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/May/2022 00:58:38] "GET /favicon.ico HTTP/1.1" 200 -
