# %%
from flask import Flask, render_template, request, redirect, session, url_for
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    post = {
        "PageId": db["results"][i]["id"],
        "Title": prop["Page"]["title"][0]["plain_text"],
        "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
        "Date": prop["Date"]["date"]["start"],
        "LastEditedTime": db["results"][i]["last_edited_time"],
        "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
        "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
        "OGImage":ogimege[0]["file"]["url"] if len(ogimege)> 0 else None,
        "Rank": prop["Rank"]["number"]}
    tags.extend(post["Tags"])
    posts.append(post)
tags_set=list(set(tags))

# %%
def make_page(p):
    item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }
        elif item_type == "embed":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Embed": item[i][item_type]["url"],
            }
        elif item_type == "bookmark":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Bookmark": item[i][item_type]["url"],
            }
        elif item_type == "link_preview":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "LinkPreview": item[i][item_type]["url"],
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

# %%
app = Flask(__name__)
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/','Blog':'/blog','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/")
def index():
    return render_template("index.html",labellist=labellist)

@app.route("/blog", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    return render_template("blog.html",labellist=labellist,posts=posts,tags=tags_set,tagname=0)

@app.route("/blog/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    return render_template("blog.html",labellist=labellist,posts=tag_page,tags=tags_set,tagname=Tag)


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Apr/2022 21:04:27] "GET /blog/ikan HTTP/1.1" 200 -
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-02-26T04:05:00.000Z',
#   'has_children': False,
#   'id': 'df6aee89-4079-4322-be70-873a16910969',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-02-26T04:05:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '楽天証券にあった投資信託のうち10万円分を試しに移管申請してみた',
#                           'text': {'content': '楽天証券にあった投資信託のうち10万円分を試しに移管申請してみた',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-02-26T04:05:00.000Z',
#   'has_children': False,
#   'id': 'f2381836-724c-4b2e-8dc4-f4fd3f7b1f7d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-02-26T04:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'もう半月くらいたつけど受領報告すらない',
#                           'text': {'content': 'もう半月くらいたつけど受領報告すらない',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-02-26T04:06:00.000Z',
#   'has_children': False,
#   'id': 'd246c733-25d4-40b0-9702-36c74e1d6c85',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-02-26T04:06:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'SBIのキャンペーンにのっかりたくて申請したけど間に合うのか。。、',
#                           'text': {'content': 'SBIのキャンペーンにのっかりたくて申請したけど間に合うのか。。、',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-02-26T04:06:00.000Z',
#   'has_children': False,
#   'id': '18953611-7301-4b89-8bee-bc80cf3778c6',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-02-26T04:07:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ていうかSBIが移管手数料なんでも代わりに払ってくれるなら楽天証券も割と儲かるのでは。。。',
#                           'text': {'content': 'ていうかSBIが移管手数料なんでも代わりに払ってくれるなら楽天証券も割と儲かるのでは。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-02-26T04:07:00.000Z',
#   'has_children': False,
#   'id': 'b6b91a5a-2674-4cb6-a451-6d7854f5c8b8',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-02-26T04:07:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '1銘柄3300円のうちどれだけ実費があるのかわからないけど3万円分しかない銘柄を10年管理するより儲かりそう。。。',
#                           'text': {'content': '1銘柄3300円のうちどれだけ実費があるのかわからないけど3万円分しかない銘柄を10年管理するより儲かりそう。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'}]
# [{'HasChildren': False,
#   'Id': 'df6aee89-4079-4322-be70-873a16910969',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '楽天証券にあった投資信託のうち10万円分を試しに移管申請してみた',
#                           'text': {'content': '楽天証券にあった投資信託のうち10万円分を試しに移管申請してみた',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'f2381836-724c-4b2e-8dc4-f4fd3f7b1f7d',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'もう半月くらいたつけど受領報告すらない',
#                           'text': {'content': 'もう半月くらいたつけど受領報告すらない',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'd246c733-25d4-40b0-9702-36c74e1d6c85',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'SBIのキャンペーンにのっかりたくて申請したけど間に合うのか。。、',
#                           'text': {'content': 'SBIのキャンペーンにのっかりたくて申請したけど間に合うのか。。、',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '18953611-7301-4b89-8bee-bc80cf3778c6',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'ていうかSBIが移管手数料なんでも代わりに払ってくれるなら楽天証券も割と儲かるのでは。。。',
#                           'text': {'content': 'ていうかSBIが移管手数料なんでも代わりに払ってくれるなら楽天証券も割と儲かるのでは。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'b6b91a5a-2674-4cb6-a451-6d7854f5c8b8',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '1銘柄3300円のうちどれだけ実費があるのかわからないけど3万円分しかない銘柄を10年管理するより儲かりそう。。。',
#                           'text': {'content': '1銘柄3300円のうちどれだけ実費があるのかわからないけど3万円分しかない銘柄を10年管理するより儲かりそう。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'}]
# 127.0.0.1 - - [03/Apr/2022 21:04:30] "GET /tag/お金系 HTTP/1.1" 200 -
# [{'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:37:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '2021年5月〜2022年1月',
#                           'text': {'content': '2021年5月〜2022年1月', 'link': None},
#                           'type': 'text'}]},
#   'id': '6c084c19-a518-4d21-b54a-20d9a303660f',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:38:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:38:00.000Z',
#   'has_children': False,
#   'id': 'f64dad5b-ee4d-42b5-b86f-162ee135a7cb',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:38:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '機械学習、深層学習の勉強をしたので単純なシステムを作ってみたのでメモ',
#                           'text': {'content': '機械学習、深層学習の勉強をしたので単純なシステムを作ってみたのでメモ',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:38:00.000Z',
#   'has_children': False,
#   'id': '713f0980-bf63-4171-ac75-393940058e37',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:40:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'いくつかパターンを試しながら5日後の価格が上がっているか20日の終値で学習',
#                           'text': {'content': 'いくつかパターンを試しながら5日後の価格が上がっているか20日の終値で学習',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:39:00.000Z',
#   'has_children': False,
#   'id': '689786a2-9e1e-4e2e-88c5-aea6f6a31a2d',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:39:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'データは2006~2020年のものを使用しました',
#                           'text': {'content': 'データは2006~2020年のものを使用しました',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:39:00.000Z',
#   'has_children': False,
#   'id': '10a005f3-14e8-48da-9bc1-bf267ac6d78c',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:40:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '個人が自動売買できる株はau株こむだけらしいのでau株こむのフリーETFを対象とした',
#                           'text': {'content': '個人が自動売買できる株はau株こむだけらしいのでau株こむのフリーETFを対象とした',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:40:00.000Z',
#   'has_children': False,
#   'id': '8975b698-5053-4c3f-ba37-4f33223319ed',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:40:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習の他損切りだけ設定（２％）',
#                           'text': {'content': '学習の他損切りだけ設定（２％）', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:40:00.000Z',
#   'has_children': False,
#   'id': 'a688f95e-7d9f-4c50-a220-8d1525c1885e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:42:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習時は-5~12%程度の年利、試験期間でバラバラすぎてよくわからないままスタート',
#                           'text': {'content': '学習時は-5~12%程度の年利、試験期間でバラバラすぎてよくわからないままスタート',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:45:00.000Z',
#   'has_children': False,
#   'id': 'dad9ab1b-d5c6-451b-9747-85d931cbddb7',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:47:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '毎日確率の高いものを３つ程度買う仕組み',
#                           'text': {'content': '毎日確率の高いものを３つ程度買う仕組み',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:42:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '実際にやってみて',
#                           'text': {'content': '実際にやってみて', 'link': None},
#                           'type': 'text'}]},
#   'id': '7b7fea45-f454-4f29-b5ab-72f56677c736',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:42:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:42:00.000Z',
#   'has_children': False,
#   'id': '59b8903d-31f1-4d76-abe6-49f3da78bb9e',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:43:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '流動性が悪すぎて指値で買えない',
#                           'text': {'content': '流動性が悪すぎて指値で買えない', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:43:00.000Z',
#   'has_children': False,
#   'id': '641f5ef5-8f75-4e61-9b28-e14537fd3f37',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:47:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '時系列を逆に読み込んでしまっていた',
#                           'text': {'content': '時系列を逆に読み込んでしまっていた',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:45:00.000Z',
#   'has_children': False,
#   'id': 'bc23edbc-0918-4395-b122-47bdb21bf3d0',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:46:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '２５万で運用し、最大マイナス１万、プラスは5000程度',
#                           'text': {'content': '２５万で運用し、最大マイナス１万、プラスは5000程度',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:46:00.000Z',
#   'has_children': False,
#   'id': '2ab707e3-8c84-4ac2-a00c-839ee109ca96',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'まともなシステムではないことを理解したが、長いこと動かすことで気づけることもあるかと',
#                           'text': {'content': 'まともなシステムではないことを理解したが、長いこと動かすことで気づけることもあるかと',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:48:00.000Z',
#   'has_children': False,
#   'id': '8e01adf4-c32b-4eda-935b-42cb2450edd7',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'そして特になかった',
#                           'text': {'content': 'そして特になかった', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:43:00.000Z',
#   'has_children': False,
#   'id': 'b51c93c3-540a-438d-9b98-1bdf2a542566',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '原油ものの変動が大きすぎて損益を大半占める',
#                           'text': {'content': '原油ものの変動が大きすぎて損益を大半占める',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:50:00.000Z',
#   'has_children': False,
#   'id': '6377b104-7ee6-4d80-ba08-d08d597c6429',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:50:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '最終的にはプラス１％で終了',
#                           'text': {'content': '最終的にはプラス１％で終了', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:44:00.000Z',
#   'has_children': False,
#   'heading_2': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'やめたきっかけ',
#                           'text': {'content': 'やめたきっかけ', 'link': None},
#                           'type': 'text'}]},
#   'id': 'fce7a930-a55f-4760-b8f1-92a03adefe29',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:45:00.000Z',
#   'object': 'block',
#   'type': 'heading_2'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:43:00.000Z',
#   'has_children': False,
#   'id': '5887c75d-3ea2-40c7-9b8e-028ad197fc63',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:44:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習用にスクレイピングで直近のデータ取っていたがapiがあることをしる',
#                           'text': {'content': '学習用にスクレイピングで直近のデータ取っていたがapiがあることをしる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:45:00.000Z',
#   'has_children': False,
#   'id': 'ef3a77c1-e874-47c3-abd7-66307b91fe5a',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:49:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '損益を記録するコードを入れていなかった',
#                           'text': {'content': '損益を記録するコードを入れていなかった',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:48:00.000Z',
#   'has_children': False,
#   'id': '7b68cbc6-9999-4006-9e09-fb508a1d4ef4',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '久しぶりにプラス域にきたこと',
#                           'text': {'content': '久しぶりにプラス域にきたこと', 'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:48:00.000Z',
#   'has_children': False,
#   'id': 'e59149b3-0c2f-45c8-b93d-fbc0bc4538ca',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:48:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '金融の勉強を少ししてポートフォリオの考え方をしる',
#                           'text': {'content': '金融の勉強を少ししてポートフォリオの考え方をしる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:49:00.000Z',
#   'has_children': False,
#   'id': '92bd0dd8-3ca2-4eef-b6d1-478d3b904083',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:50:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'グラフで資産推移とか見せれたらそれっぽいのだけど。。。ブログにすることもなかったので終了。。。',
#                           'text': {'content': 'グラフで資産推移とか見せれたらそれっぽいのだけど。。。ブログにすることもなかったので終了。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'type': 'paragraph'},
#  {'archived': False,
#   'created_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                  'object': 'user'},
#   'created_time': '2022-01-18T11:46:00.000Z',
#   'has_children': False,
#   'id': 'e5984e4d-7d68-4cb5-83fd-3fb1498a1c05',
#   'last_edited_by': {'id': 'f081e896-45b8-4a40-9079-c171b91b946e',
#                      'object': 'user'},
#   'last_edited_time': '2022-01-18T11:46:00.000Z',
#   'object': 'block',
#   'paragraph': {'color': 'default', 'text': []},
#   'type': 'paragraph'}]
# [{'HasChildren': False,
#   'Id': '6c084c19-a518-4d21-b54a-20d9a303660f',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '2021年5月〜2022年1月',
#                           'text': {'content': '2021年5月〜2022年1月', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': 'f64dad5b-ee4d-42b5-b86f-162ee135a7cb',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '機械学習、深層学習の勉強をしたので単純なシステムを作ってみたのでメモ',
#                           'text': {'content': '機械学習、深層学習の勉強をしたので単純なシステムを作ってみたのでメモ',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '713f0980-bf63-4171-ac75-393940058e37',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'いくつかパターンを試しながら5日後の価格が上がっているか20日の終値で学習',
#                           'text': {'content': 'いくつかパターンを試しながら5日後の価格が上がっているか20日の終値で学習',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '689786a2-9e1e-4e2e-88c5-aea6f6a31a2d',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'データは2006~2020年のものを使用しました',
#                           'text': {'content': 'データは2006~2020年のものを使用しました',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '10a005f3-14e8-48da-9bc1-bf267ac6d78c',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations':
# 127.0.0.1 - - [03/Apr/2022 21:04:34] "GET /blog/aukabu HTTP/1.1" 200 -
# {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '個人が自動売買できる株はau株こむだけらしいのでau株こむのフリーETFを対象とした',
#                           'text': {'content': '個人が自動売買できる株はau株こむだけらしいのでau株こむのフリーETFを対象とした',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '8975b698-5053-4c3f-ba37-4f33223319ed',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習の他損切りだけ設定（２％）',
#                           'text': {'content': '学習の他損切りだけ設定（２％）', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'a688f95e-7d9f-4c50-a220-8d1525c1885e',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習時は-5~12%程度の年利、試験期間でバラバラすぎてよくわからないままスタート',
#                           'text': {'content': '学習時は-5~12%程度の年利、試験期間でバラバラすぎてよくわからないままスタート',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'dad9ab1b-d5c6-451b-9747-85d931cbddb7',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '毎日確率の高いものを３つ程度買う仕組み',
#                           'text': {'content': '毎日確率の高いものを３つ程度買う仕組み',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '7b7fea45-f454-4f29-b5ab-72f56677c736',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '実際にやってみて',
#                           'text': {'content': '実際にやってみて', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '59b8903d-31f1-4d76-abe6-49f3da78bb9e',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '流動性が悪すぎて指値で買えない',
#                           'text': {'content': '流動性が悪すぎて指値で買えない', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '641f5ef5-8f75-4e61-9b28-e14537fd3f37',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '時系列を逆に読み込んでしまっていた',
#                           'text': {'content': '時系列を逆に読み込んでしまっていた',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'bc23edbc-0918-4395-b122-47bdb21bf3d0',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '２５万で運用し、最大マイナス１万、プラスは5000程度',
#                           'text': {'content': '２５万で運用し、最大マイナス１万、プラスは5000程度',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '2ab707e3-8c84-4ac2-a00c-839ee109ca96',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'まともなシステムではないことを理解したが、長いこと動かすことで気づけることもあるかと',
#                           'text': {'content': 'まともなシステムではないことを理解したが、長いこと動かすことで気づけることもあるかと',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '8e01adf4-c32b-4eda-935b-42cb2450edd7',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'そして特になかった',
#                           'text': {'content': 'そして特になかった', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'b51c93c3-540a-438d-9b98-1bdf2a542566',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '原油ものの変動が大きすぎて損益を大半占める',
#                           'text': {'content': '原油ものの変動が大きすぎて損益を大半占める',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '6377b104-7ee6-4d80-ba08-d08d597c6429',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '最終的にはプラス１％で終了',
#                           'text': {'content': '最終的にはプラス１％で終了', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'fce7a930-a55f-4760-b8f1-92a03adefe29',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'やめたきっかけ',
#                           'text': {'content': 'やめたきっかけ', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'heading_2'},
#  {'HasChildren': False,
#   'Id': '5887c75d-3ea2-40c7-9b8e-028ad197fc63',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '学習用にスクレイピングで直近のデータ取っていたがapiがあることをしる',
#                           'text': {'content': '学習用にスクレイピングで直近のデータ取っていたがapiがあることをしる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'ef3a77c1-e874-47c3-abd7-66307b91fe5a',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '損益を記録するコードを入れていなかった',
#                           'text': {'content': '損益を記録するコードを入れていなかった',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '7b68cbc6-9999-4006-9e09-fb508a1d4ef4',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '久しぶりにプラス域にきたこと',
#                           'text': {'content': '久しぶりにプラス域にきたこと', 'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'e59149b3-0c2f-45c8-b93d-fbc0bc4538ca',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': '金融の勉強を少ししてポートフォリオの考え方をしる',
#                           'text': {'content': '金融の勉強を少ししてポートフォリオの考え方をしる',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': '92bd0dd8-3ca2-4eef-b6d1-478d3b904083',
#   'RichTexts': {'color': 'default',
#                 'text': [{'annotations': {'bold': False,
#                                           'code': False,
#                                           'color': 'default',
#                                           'italic': False,
#                                           'strikethrough': False,
#                                           'underline': False},
#                           'href': None,
#                           'plain_text': 'グラフで資産推移とか見せれたらそれっぽいのだけど。。。ブログにすることもなかったので終了。。。',
#                           'text': {'content': 'グラフで資産推移とか見せれたらそれっぽいのだけど。。。ブログにすることもなかったので終了。。。',
#                                    'link': None},
#                           'type': 'text'}]},
#   'Type': 'paragraph'},
#  {'HasChildren': False,
#   'Id': 'e5984e4d-7d68-4cb5-83fd-3fb1498a1c05',
#   'RichTexts': {'text': [{'plain_text': ''}]},
#   'Type': 'paragraph'}]
