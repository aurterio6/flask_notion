# %%
from flask import Flask, render_template, request, redirect, session, url_for
import os
from dotenv import load_dotenv
from pprint import pprint
from notion_client import Client
# .envファイルの内容を読み込みます
load_dotenv()

# os.environを用いて環境変数を表示させます
DATABASE_ID=os.environ['DATABASE_ID']
NOTION_API_SECRET=os.environ['NOTION_API_SECRET']

notion = Client(auth=NOTION_API_SECRET)
db = notion.databases.query(
    **{
        'database_id' : DATABASE_ID  # データベースID
       }
)
    
posts=[]
tags=[]
for i in range(len(db["results"])):
    prop=db["results"][i]["properties"]
    excerpt=prop["Excerpt"]["rich_text"]
    ogimege=prop["OGImage"]["files"]
    if prop["Published"]["checkbox"]:
        post = {
            "PageId": db["results"][i]["id"],
            "Title": prop["Page"]["title"][0]["plain_text"],
            "Slug": prop["Slug"]["rich_text"][0]["plain_text"],
            "Date": prop["Date"]["date"]["start"],
            "LastEditedTime": db["results"][i]["last_edited_time"][:10],
            "Tags": list(map(lambda x:x["name"] ,prop["Tags"]["multi_select"])),
            "Excerpt":excerpt[0]["plain_text"] if len(excerpt)> 0 else "",
            "OGImage":ogimege[0]["file"]["url"] if len(ogimege)> 0 else None,
            "Rank": prop["Rank"]["number"]}
        tags.extend(post["Tags"])
        posts.append(post)
tags_set=list(set(tags))

# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
def get_title(html):
    """Scrape page title."""
    title = None
    if type(html.title)==str:
        title = html.title.string
    elif html.find("meta", property="og:title"):
        title = html.find("meta", property="og:title").get('content')
    elif html.find("meta", property="twitter:title"):
        title = html.find("meta", property="twitter:title").get('content')
    elif html.find("h1"):
        title = html.find("h1").string
    return title


def get_description(html):
    """Scrape page description."""
    description = None
    if html.find("meta", property="description"):
        description = html.find("meta", property="description").get('content')
    elif html.find("meta", property="og:description"):
        description = html.find("meta", property="og:description").get('content')
    elif html.find("meta", property="twitter:description"):
        description = html.find("meta", property="twitter:description").get('content')
    elif html.find("p"):
        description = html.find("p").contents
    return description


def get_image(html):
    """Scrape share image."""
    image = None
    if html.find("meta", property="image"):
        image = html.find("meta", property="image").get('content')
    elif html.find("meta", property="og:image"):
        image = html.find("meta", property="og:image").get('content')
    elif html.find("meta", property="twitter:image"):
        image = html.find("meta", property="twitter:image").get('content')
    elif html.find("img", src=True):
        image = html.find("img").get('src')
    return image

def generate_preview(url):
    req = requests.get(url, headers)
    html = BeautifulSoup(req.content, 'html.parser')
    meta_data = {
       'title': get_title(html),
       'description': get_description(html),
       'image': get_image(html),
    }
    return meta_data


def make_page(p):
    item = notion.blocks.children.list(block_id=posts[p]["PageId"])["results"]
    blocks = []
    pprint(item)
    for i in range(len(item)):
        item_type = item[i]["type"]
        if (
            item_type
            in [
                "paragraph",
                "heading_1",
                "heading_2",
                "heading_3",
                "bulleted_list_item",
                "numbered_list_item",
            ]
            and len(item[i][item_type]["text"]) > 0
        ):
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
            }
        elif item_type == "image":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i]["image"]["caption"],
                "Image": item[i]["image"]["file"]["url"]
                if item[i]["image"]["type"] == "file"
                else item[i]["image"]["external"]["url"],
            }
        elif item_type == "code":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Caption": item[i][item_type]["caption"],
                "Text": item[i][item_type],
                "Language": item[i]["code"]["language"],
            }
        elif item_type == "quote":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Quote": item[i][item_type],
            }
        elif item_type == "callout":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts": item[i][item_type],
                "Icon": item[i][item_type]["icon"]["emoji"],
            }

        elif item_type in ["link_preview","bookmark","embed"]:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Url":item[i][item_type]["url"],
                "LinkPreview": generate_preview(item[i][item_type]["url"]),
            }
        elif item_type == "table":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "Table": {
                    "TableWidth": item[i][item_type]["table_width"],
                    "HasColumnHeader": item[i][item_type]["has_column_header"],
                    "HasRowHeader": item[i][item_type]["has_row_header"],
                    "Rows": [],
                },
            }
        elif item_type == "table_row":
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "TableRow": item[i][item_type]["cells"],
            }
        else:
            block = {
                "Id": item[i]["id"],
                "Type": item_type,
                "HasChildren": item[i]["has_children"],
                "RichTexts":{"text":[{"plain_text":""}]}#空白行にしたいので追加
            }
        blocks.append(block)
    return blocks

# %%
app = Flask(__name__)
app.secret_key = "tekitou"  # os.urandom(32)などが良い。が、herokuで安定しないとのコメントあり。
labellist={ 'Home':'/','Blog':'/blog','Wishlist':'https://pushy-kitty-07b.notion.site/PC-3a8f8fc1fdb243649a2bbb1cbcb41f11',}
# 何も描かないとGETしか受け付けない。ブログならそれでOK
# https://shigeblog221.com/python-flask4/
@app.route("/")
def index():
    return render_template("index.html",labellist=labellist,tags=tags_set)

@app.route("/blog", methods=["GET", "POST"])
def blog():
    #if len(posts)>10:
        #post_list=posts[:10]
    #else:
        #post_list=posts
    return render_template("blog.html",labellist=labellist,posts=posts,tags=tags_set,tagname=0)

@app.route("/blog/<Slug>", methods=["GET", "POST"])
def page(Slug):
    for p in range(len(posts)):
        if posts[p]["Slug"]==Slug:
            page_num=p
            break
    blocks=make_page(page_num)
    pprint(blocks)
    return render_template("slug.html",labellist=labellist,post=posts[p],blocks=blocks,tags=tags_set)

@app.route("/tag/<Tag>", methods=["GET", "POST"])
def tagpage(Tag):
    tag_page=[]
    for p in range(len(posts)):
        if Tag in posts[p]["Tags"]:
            tag_page.append(posts[p])
    return render_template("blog.html",labellist=labellist,posts=tag_page,tags=tags_set,tagname=Tag)


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:44] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:55:45] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 18:56:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:56:58] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:49] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:57:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:07] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:16] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:58:17] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 18:59:47] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:15] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:16] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:29] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:00:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:28] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:01:29] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:14] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:23] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:24] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:02:46] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:06:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:33] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:33] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:33] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:33] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:34] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:34] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:34] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:06:34] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:11] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:44] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:07:45] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:09] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:23] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:32] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:33] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:40] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:40] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:41] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:43] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:49] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:08:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:28] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:36] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:37] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:55] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:56] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:09:56] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:47] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:10:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:10:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:02] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:25] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:11:26] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/footer.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/header.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:08] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:13:09] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:48] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:49] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:27:51] "GET /blog HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:27:51] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:27:51] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:28:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:28:11] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:28:11] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:38] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:29:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/colorjoe.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/page.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/shared.module.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/js/card.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:30:20] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:42:33] "GET /blog HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:42:33] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:42:33] "GET /static/css/footer.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:43:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 19:43:01] "GET /static/css/header.module.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Apr/2022 19:43:01] "GET /static/css/footer.module.css HTTP/1.1" 404 -
